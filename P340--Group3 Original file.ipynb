# %%
# %config FrozenModules.builtins = ''

# %%
import pandas as pd
import numpy as np
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
import re
import nltk
from nltk.tokenize import word_tokenize
from textblob import TextBlob 
from nltk.corpus import stopwords
from nltk import pos_tag
from wordcloud import WordCloud
from nltk import FreqDist
from collections import Counter
from nltk import ngrams
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize
from textblob import TextBlob
from sklearn.metrics import accuracy_score, classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.dummy import DummyClassifier

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # loading data

# %%
df=pd.read_csv("financial_sentiment_data.csv")

# %%
df
# Out:
#                                                Sentence Sentiment
# 0     The GeoSolutions technology will leverage Bene...  positive
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2     For the last quarter of 2010 , Componenta 's n...  positive
# 3     According to the Finnish-Russian Chamber of Co...   neutral
# 4     The Swedish buyout firm has sold its remaining...   neutral
# ...                                                 ...       ...
# 5837  RISING costs have forced packaging producer Hu...  negative
# 5838  Nordic Walking was first used as a summer trai...   neutral
# 5839  According shipping company Viking Line , the E...   neutral
# 5840  In the building and home improvement trade , s...   neutral
# 5841  HELSINKI AFX - KCI Konecranes said it has won ...  positive
#
# [5842 rows x 2 columns]

# %%
df.head(10)
# Out:
#                                             Sentence Sentiment
# 0  The GeoSolutions technology will leverage Bene...  positive
# 1  $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2  For the last quarter of 2010 , Componenta 's n...  positive
# 3  According to the Finnish-Russian Chamber of Co...   neutral
# 4  The Swedish buyout firm has sold its remaining...   neutral
# 5    $SPY wouldn't be surprised to see a green close  positive
# 6  Shell's $70 Billion BG Deal Meets Shareholder ...  negative
# 7  SSH COMMUNICATIONS SECURITY CORP STOCK EXCHANG...  negative
# 8  Kone 's net sales rose by some 14 % year-on-ye...  positive
# 9  The Stockmann department store will have a tot...   neutral

# %%
df.tail(10)
# Out:
#                                                Sentence Sentiment
# 5832  Operating profit fell to EUR 38.1 mn from EUR ...  negative
# 5833  In 2008 , Kemira recorded revenue of approxima...   neutral
# 5834  Investments in product development stood at 6....   neutral
# 5835  HSBC Says Unit to Book $585 Million Charge on ...  negative
# 5836  Daily Mail parent company in talks with potent...  positive
# 5837  RISING costs have forced packaging producer Hu...  negative
# 5838  Nordic Walking was first used as a summer trai...   neutral
# 5839  According shipping company Viking Line , the E...   neutral
# 5840  In the building and home improvement trade , s...   neutral
# 5841  HELSINKI AFX - KCI Konecranes said it has won ...  positive

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5842 entries, 0 to 5841
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Sentence   5842 non-null   object
#  1   Sentiment  5842 non-null   object
# dtypes: object(2)
# memory usage: 91.4+ KB

# %%
#columns

# %%
df.columns
# Out:
# Index(['Sentence', 'Sentiment'], dtype='object')

# %% [markdown]
# # Data Cleaning

# %%
#finding missing values

# %%
missing_values=df.isnull().sum()

# %%
missing_values
# Out:
# Sentence     0
# Sentiment    0
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
missing_values.plot(kind='bar')
plt.title('Missing Values in Each Column')
plt.xlabel('Columns')
plt.ylabel('Number of Missing Values')
plt.show()

# %% [markdown]
# # Sentiment

# %%
#unique values in column sentiment

# %%
df['Sentiment'].nunique()
# Out:
# 3

# %%
df['Sentiment'].unique()
# Out:
# array(['positive', 'negative', 'neutral'], dtype=object)

# %%
 df['Sentiment'].value_counts()
# Out:
# neutral     3130
# positive    1852
# negative     860
# Name: Sentiment, dtype: int64

# %%
#plotting sentiments
sns.countplot(x='Sentiment', data=df)
plt.title('Distribution of Sentiments')
plt.show()

# %% [markdown]
# # Sentence

# %%
#unique values in column sentence

# %%
df['Sentence'].nunique()
# Out:
# 5322

# %%
df['Sentence'].unique()
# Out:
# array(["The GeoSolutions technology will leverage Benefon 's GPS solutions by providing Location Based Search Technology , a Communities Platform , location relevant multimedia content and a new and powerful commercial model .",
#        '$ESI on lows, down $1.50 to $2.50 BK a real possibility',
#        "For the last quarter of 2010 , Componenta 's net sales doubled to EUR131m from EUR76m for the same period a year earlier , while it moved to a zero pre-tax profit from a pre-tax loss of EUR7m .",
#        ...,
#        'Nordic Walking was first used as a summer training method by cross-country skiers .',
#        'According shipping company Viking Line , the EU decision will have a significant financial impact .',
#        'HELSINKI AFX - KCI Konecranes said it has won an order for four hot metal ladle cranes from Indian steel producer Bhushan Steel and Strips Ltd. .'],
#       dtype=object)

# %%
#understanding the data

# %%
sentence1, sentiment1 = df["Sentence"][0], df["Sentiment"][0]

# %%
sentence1
# Out:
# "The GeoSolutions technology will leverage Benefon 's GPS solutions by providing Location Based Search Technology , a Communities Platform , location relevant multimedia content and a new and powerful commercial model ."

# %%
sentiment1
# Out:
# 'positive'

# %%
sentence2, sentiment2 = df["Sentence"][5832], df["Sentiment"][5832]

# %%
sentence2
# Out:
# 'Operating profit fell to EUR 38.1 mn from EUR 55.3 mn in 2007 .'

# %%
sentiment2
# Out:
# 'negative'

# %%
sentence3, sentiment3 = df["Sentence"][3], df["Sentiment"][3]

# %%
sentence3
# Out:
# 'According to the Finnish-Russian Chamber of Commerce , all the major construction companies of Finland are operating in Russia .'

# %%
 sentiment3
# Out:
# 'neutral'

# %%
#duplicate columns

# %%
sentence_duplicates = df[df['Sentence'].duplicated(keep=False)]

# %%
sentence_duplicates
# Out:
#                                                Sentence Sentiment
# 7     SSH COMMUNICATIONS SECURITY CORP STOCK EXCHANG...  negative
# 13             Viking Line has canceled some services .   neutral
# 41    Dolce & Gabbana has asked the European Union t...  negative
# 57    Diluted earnings per share ( EPS ) fell to EUR...   neutral
# 66    Finnish GeoSentric 's net sales decreased to E...  negative
# ...                                                 ...       ...
# 5827  ( ADPnews ) - Oct 21 , 2009 - Finland-based IT...  negative
# 5831  Finnish developer and manufacturer of mobile p...  negative
# 5832  Operating profit fell to EUR 38.1 mn from EUR ...  negative
# 5837  RISING costs have forced packaging producer Hu...  negative
# 5840  In the building and home improvement trade , s...   neutral
#
# [1040 rows x 2 columns]

# %%
sentence_duplicates.count()
# Out:
# Sentence     1040
# Sentiment    1040
# dtype: int64

# %%
#all duplicates in the data frame

# %%
all_duplicates = df[df.duplicated(keep=False)]

# %%
all_duplicates
# Out:
#                                                Sentence Sentiment
# 629   Proha Plc ( Euronext :7327 ) announced today (...   neutral
# 815   SSH Communications Security Corporation is hea...   neutral
# 1825  Proha Plc ( Euronext :7327 ) announced today (...   neutral
# 1859  SSH Communications Security Corporation is hea...   neutral
# 2234  Ahlstrom 's share is quoted on the NASDAQ OMX ...   neutral
# 2553  The issuer is solely responsible for the conte...   neutral
# 2672  Ahlstrom 's share is quoted on the NASDAQ OMX ...   neutral
# 3079  The company serves customers in various indust...   neutral
# 3272  The company serves customers in various indust...   neutral
# 3353  The report profiles 614 companies including ma...   neutral
# 3986  The issuer is solely responsible for the conte...   neutral
# 5342  The report profiles 614 companies including ma...   neutral

# %%
all_duplicates.count()
# Out:
# Sentence     12
# Sentiment    12
# dtype: int64

# %%
all_duplicates.nunique()
# Out:
# Sentence     6
# Sentiment    1
# dtype: int64

# %%
all_duplicate_counts = all_duplicates['Sentence'].value_counts()

# %%
all_duplicate_counts
# Out:
# Proha Plc ( Euronext :7327 ) announced today ( 19 May ) that its fully-owned subsidiary , Safran Software Solutions AS , has agreed to sell its 49 % share of Safran North America LLC to a SNA Holding AS , an investment group based in Norway .                                                          2
# SSH Communications Security Corporation is headquartered in Helsinki , Finland .                                                                                                                                                                                                                            2
# Ahlstrom 's share is quoted on the NASDAQ OMX Helsinki .                                                                                                                                                                                                                                                    2
# The issuer is solely responsible for the content of this announcement .                                                                                                                                                                                                                                     2
# The company serves customers in various industries , including process and resources , industrial machinery , architecture , building , construction , electrical , transportation , electronics , chemical , petrochemical , energy , and information technology , as well as catering and households .    2
# The report profiles 614 companies including many key and niche players worldwide such as Black & Decker Corporation , Fiskars Corporation , Fiskars Brands , Inc. , Husqvarna Outdoor Products Inc. , K+S Group , Ryobi Technologies , Inc. , The Scotts Miracle-Gro Company , and Van Group , Inc. .       2
# Name: Sentence, dtype: int64

# %%
# Plot a bar chart
plt.figure(figsize=(10, 6))
all_duplicate_counts.plot(kind='bar', color='skyblue')
plt.title('Overall Duplicate Values in DataFrame')
plt.xlabel('Sentence')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Remove overall duplicates in the entire DataFrame
df_no_duplicates = df.drop_duplicates()

# %%
# Display the resulting DataFrames
print("DataFrame without overall duplicates:")
df_no_duplicates
# Out:
# DataFrame without overall duplicates:
#                                                Sentence Sentiment
# 0     The GeoSolutions technology will leverage Bene...  positive
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2     For the last quarter of 2010 , Componenta 's n...  positive
# 3     According to the Finnish-Russian Chamber of Co...   neutral
# 4     The Swedish buyout firm has sold its remaining...   neutral
# ...                                                 ...       ...
# 5837  RISING costs have forced packaging producer Hu...  negative
# 5838  Nordic Walking was first used as a summer trai...   neutral
# 5839  According shipping company Viking Line , the E...   neutral
# 5840  In the building and home improvement trade , s...   neutral
# 5841  HELSINKI AFX - KCI Konecranes said it has won ...  positive
#
# [5836 rows x 2 columns]

# %%
df=df_no_duplicates.copy()

# %% [markdown]
# # text processing

# %%
#cleaning data frame in the means of white spaces,special characters and numbers
df['Sentence'] = df['Sentence'].str.replace('-', ' ')

# %%
df
# Out:
#                                                Sentence Sentiment
# 0     The GeoSolutions technology will leverage Bene...  positive
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2     For the last quarter of 2010 , Componenta 's n...  positive
# 3     According to the Finnish Russian Chamber of Co...   neutral
# 4     The Swedish buyout firm has sold its remaining...   neutral
# ...                                                 ...       ...
# 5837  RISING costs have forced packaging producer Hu...  negative
# 5838  Nordic Walking was first used as a summer trai...   neutral
# 5839  According shipping company Viking Line , the E...   neutral
# 5840  In the building and home improvement trade , s...   neutral
# 5841  HELSINKI AFX   KCI Konecranes said it has won ...  positive
#
# [5836 rows x 2 columns]

# %% [markdown]
# removing special characters and numbers

# %%
def clean_data(text):
    # Remove URLs
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    return text

# %%
#putting the cleaned data into another coumn named"Sentence_clean"

# %%
df['Clean_Sentence'] = df['Sentence'].apply(clean_data)
df.head(5)
# Out:
#                                             Sentence Sentiment  \
# 0  The GeoSolutions technology will leverage Bene...  positive
# 1  $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2  For the last quarter of 2010 , Componenta 's n...  positive
# 3  According to the Finnish Russian Chamber of Co...   neutral
# 4  The Swedish buyout firm has sold its remaining...   neutral
#
#                                       Clean_Sentence
# 0  The GeoSolutions technology will leverage Bene...
# 1        ESI on lows down  to  BK a real possibility
# 2  For the last quarter of   Componenta s net sal...
# 3  According to the Finnish Russian Chamber of Co...
# 4  The Swedish buyout firm has sold its remaining...

# %% [markdown]
# case changing

# %%
#chaning the word case in the  column "sentence_clean" in the data frame

# %%
df['Clean_Sentence'] = df['Clean_Sentence'].str.lower()

# %%
df
# Out:
#                                                Sentence Sentiment  \
# 0     The GeoSolutions technology will leverage Bene...  positive
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2     For the last quarter of 2010 , Componenta 's n...  positive
# 3     According to the Finnish Russian Chamber of Co...   neutral
# 4     The Swedish buyout firm has sold its remaining...   neutral
# ...                                                 ...       ...
# 5837  RISING costs have forced packaging producer Hu...  negative
# 5838  Nordic Walking was first used as a summer trai...   neutral
# 5839  According shipping company Viking Line , the E...   neutral
# 5840  In the building and home improvement trade , s...   neutral
# 5841  HELSINKI AFX   KCI Konecranes said it has won ...  positive
#
#                                          Clean_Sentence
# 0     the geosolutions technology will leverage bene...
# 1           esi on lows down  to  bk a real possibility
# 2     for the last quarter of   componenta s net sal...
# 3     according to the finnish russian chamber of co...
# 4     the swedish buyout firm has sold its remaining...
# ...                                                 ...
# 5837  rising costs have forced packaging producer hu...
# 5838  nordic walking was first used as a summer trai...
# 5839  according shipping company viking line  the eu...
# 5840  in the building and home improvement trade  sa...
# 5841  helsinki afx   kci konecranes said it has won ...
#
# [5836 rows x 3 columns]

# %%
#after removing all white spaces and numbers and special characters and lowering the word cases putting data into "train_df" data frame

# %%
train_df=pd.DataFrame(df)

# %%
train_df
# Out:
#                                                Sentence Sentiment  \
# 0     The GeoSolutions technology will leverage Bene...  positive
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2     For the last quarter of 2010 , Componenta 's n...  positive
# 3     According to the Finnish Russian Chamber of Co...   neutral
# 4     The Swedish buyout firm has sold its remaining...   neutral
# ...                                                 ...       ...
# 5837  RISING costs have forced packaging producer Hu...  negative
# 5838  Nordic Walking was first used as a summer trai...   neutral
# 5839  According shipping company Viking Line , the E...   neutral
# 5840  In the building and home improvement trade , s...   neutral
# 5841  HELSINKI AFX   KCI Konecranes said it has won ...  positive
#
#                                          Clean_Sentence
# 0     the geosolutions technology will leverage bene...
# 1           esi on lows down  to  bk a real possibility
# 2     for the last quarter of   componenta s net sal...
# 3     according to the finnish russian chamber of co...
# 4     the swedish buyout firm has sold its remaining...
# ...                                                 ...
# 5837  rising costs have forced packaging producer hu...
# 5838  nordic walking was first used as a summer trai...
# 5839  according shipping company viking line  the eu...
# 5840  in the building and home improvement trade  sa...
# 5841  helsinki afx   kci konecranes said it has won ...
#
# [5836 rows x 3 columns]

# %% [markdown]
# tokenization

# %%
# Tokenize the 'Clean_Sentence' column
train_df['tokenized_Clean_Sentence'] = train_df['Clean_Sentence'].apply(lambda x: word_tokenize(x))

# %%
train_df['Clean_Sentence']
# Out:
# 0       the geosolutions technology will leverage bene...
# 1             esi on lows down  to  bk a real possibility
# 2       for the last quarter of   componenta s net sal...
# 3       according to the finnish russian chamber of co...
# 4       the swedish buyout firm has sold its remaining...
#                               ...
# 5837    rising costs have forced packaging producer hu...
# 5838    nordic walking was first used as a summer trai...
# 5839    according shipping company viking line  the eu...
# 5840    in the building and home improvement trade  sa...
# 5841    helsinki afx   kci konecranes said it has won ...
# Name: Clean_Sentence, Length: 5836, dtype: object

# %%
train_df['tokenized_Clean_Sentence']
# Out:
# 0       [the, geosolutions, technology, will, leverage...
# 1       [esi, on, lows, down, to, bk, a, real, possibi...
# 2       [for, the, last, quarter, of, componenta, s, n...
# 3       [according, to, the, finnish, russian, chamber...
# 4       [the, swedish, buyout, firm, has, sold, its, r...
#                               ...
# 5837    [rising, costs, have, forced, packaging, produ...
# 5838    [nordic, walking, was, first, used, as, a, sum...
# 5839    [according, shipping, company, viking, line, t...
# 5840    [in, the, building, and, home, improvement, tr...
# 5841    [helsinki, afx, kci, konecranes, said, it, has...
# Name: tokenized_Clean_Sentence, Length: 5836, dtype: object

# %%
# Lemmatization
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
train_df['Lemmatized_Sentence'] = train_df['Clean_Sentence'].apply(
    lambda tokens: [lemmatizer.lemmatize(word) for word in tokens])
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\V1V3K\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
train_df
# Out:
#                                                Sentence Sentiment  \
# 0     The GeoSolutions technology will leverage Bene...  positive
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2     For the last quarter of 2010 , Componenta 's n...  positive
# 3     According to the Finnish Russian Chamber of Co...   neutral
# 4     The Swedish buyout firm has sold its remaining...   neutral
# ...                                                 ...       ...
# 5837  RISING costs have forced packaging producer Hu...  negative
# 5838  Nordic Walking was first used as a summer trai...   neutral
# 5839  According shipping company Viking Line , the E...   neutral
# 5840  In the building and home improvement trade , s...   neutral
# 5841  HELSINKI AFX   KCI Konecranes said it has won ...  positive
#
#                                          Clean_Sentence  \
# 0     the geosolutions technology will leverage bene...
# 1           esi on lows down  to  bk a real possibility
# 2     for the last quarter of   componenta s net sal...
# 3     according to the finnish russian chamber of co...
# 4     the swedish buyout firm has sold its remaining...
# ...                                                 ...
# 5837  rising costs have forced packaging producer hu...
# 5838  nordic walking was first used as a summer trai...
# 5839  according shipping company viking line  the eu...
# 5840  in the building and home improvement trade  sa...
# 5841  helsinki afx   kci konecranes said it has won ...
#
#                                tokenized_Clean_Sentence  \
# 0     [the, geosolutions, technology, will, leverage...
# 1     [esi, on, lows, down, to, bk, a, real, possibi...
# 2     [for, the, last, quarter, of, componenta, s, n...
# 3     [according, to, the, finnish, russian, chamber...
# 4     [the, swedish, buyout, firm, has, sold, its, r...
# ...                                                 ...
# 5837  [rising, costs, have, forced, packaging, produ...
# 5838  [nordic, walking, was, first, used, as, a, sum...
# 5839  [according, shipping, company, viking, line, t...
# 5840  [in, the, building, and, home, improvement, tr...
# 5841  [helsinki, afx, kci, konecranes, said, it, has...
#
#                                     Lemmatized_Sentence
# 0     [t, h, e,  , g, e, o, s, o, l, u, t, i, o, n, ...
# 1     [e, s, i,  , o, n,  , l, o, w, s,  , d, o, w, ...
# 2     [f, o, r,  , t, h, e,  , l, a, s, t,  , q, u, ...
# 3     [a, c, c, o, r, d, i, n, g,  , t, o,  , t, h, ...
# 4     [t, h, e,  , s, w, e, d, i, s, h,  , b, u, y, ...
# ...                                                 ...
# 5837  [r, i, s, i, n, g,  , c, o, s, t, s,  , h, a, ...
# 5838  [n, o, r, d, i, c,  , w, a, l, k, i, n, g,  , ...
# 5839  [a, c, c, o, r, d, i, n, g,  , s, h, i, p, p, ...
# 5840  [i, n,  , t, h, e,  , b, u, i, l, d, i, n, g, ...
# 5841  [h, e, l, s, i, n, k, i,  , a, f, x,  ,  ,  , ...
#
# [5836 rows x 5 columns]

# %% [markdown]
# stopwords

# %%
#removing stop words

# %%
stop_words = set(stopwords.words('english'))

# %%
# Remove stop words from each tokenized sentence
train_df['tokenized_Clean_Sentence_without_stopwords'] = train_df['tokenized_Clean_Sentence'].apply(
    lambda tokens: [word for word in tokens if word.lower() not in stop_words])
train_df['tokenized_Clean_Sentence']
# Out:
# 0       [the, geosolutions, technology, will, leverage...
# 1       [esi, on, lows, down, to, bk, a, real, possibi...
# 2       [for, the, last, quarter, of, componenta, s, n...
# 3       [according, to, the, finnish, russian, chamber...
# 4       [the, swedish, buyout, firm, has, sold, its, r...
#                               ...
# 5837    [rising, costs, have, forced, packaging, produ...
# 5838    [nordic, walking, was, first, used, as, a, sum...
# 5839    [according, shipping, company, viking, line, t...
# 5840    [in, the, building, and, home, improvement, tr...
# 5841    [helsinki, afx, kci, konecranes, said, it, has...
# Name: tokenized_Clean_Sentence, Length: 5836, dtype: object

# %%
train_df['tokenized_Clean_Sentence_without_stopwords']
# Out:
# 0       [geosolutions, technology, leverage, benefon, ...
# 1                      [esi, lows, bk, real, possibility]
# 2       [last, quarter, componenta, net, sales, double...
# 3       [according, finnish, russian, chamber, commerc...
# 4       [swedish, buyout, firm, sold, remaining, perce...
#                               ...
# 5837    [rising, costs, forced, packaging, producer, h...
# 5838    [nordic, walking, first, used, summer, trainin...
# 5839    [according, shipping, company, viking, line, e...
# 5840    [building, home, improvement, trade, sales, de...
# 5841    [helsinki, afx, kci, konecranes, said, order, ...
# Name: tokenized_Clean_Sentence_without_stopwords, Length: 5836, dtype: object

# %%
train_df
# Out:
#                                                Sentence Sentiment  \
# 0     The GeoSolutions technology will leverage Bene...  positive
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2     For the last quarter of 2010 , Componenta 's n...  positive
# 3     According to the Finnish Russian Chamber of Co...   neutral
# 4     The Swedish buyout firm has sold its remaining...   neutral
# ...                                                 ...       ...
# 5837  RISING costs have forced packaging producer Hu...  negative
# 5838  Nordic Walking was first used as a summer trai...   neutral
# 5839  According shipping company Viking Line , the E...   neutral
# 5840  In the building and home improvement trade , s...   neutral
# 5841  HELSINKI AFX   KCI Konecranes said it has won ...  positive
#
#                                          Clean_Sentence  \
# 0     the geosolutions technology will leverage bene...
# 1           esi on lows down  to  bk a real possibility
# 2     for the last quarter of   componenta s net sal...
# 3     according to the finnish russian chamber of co...
# 4     the swedish buyout firm has sold its remaining...
# ...                                                 ...
# 5837  rising costs have forced packaging producer hu...
# 5838  nordic walking was first used as a summer trai...
# 5839  according shipping company viking line  the eu...
# 5840  in the building and home improvement trade  sa...
# 5841  helsinki afx   kci konecranes said it has won ...
#
#                                tokenized_Clean_Sentence  \
# 0     [the, geosolutions, technology, will, leverage...
# 1     [esi, on, lows, down, to, bk, a, real, possibi...
# 2     [for, the, last, quarter, of, componenta, s, n...
# 3     [according, to, the, finnish, russian, chamber...
# 4     [the, swedish, buyout, firm, has, sold, its, r...
# ...                                                 ...
# 5837  [rising, costs, have, forced, packaging, produ...
# 5838  [nordic, walking, was, first, used, as, a, sum...
# 5839  [according, shipping, company, viking, line, t...
# 5840  [in, the, building, and, home, improvement, tr...
# 5841  [helsinki, afx, kci, konecranes, said, it, has...
#
#                                     Lemmatized_Sentence  \
# 0     [t, h, e,  , g, e, o, s, o, l, u, t, i, o, n, ...
# 1     [e, s, i,  , o, n,  , l, o, w, s,  , d, o, w, ...
# 2     [f, o, r,  , t, h, e,  , l, a, s, t,  , q, u, ...
# 3     [a, c, c, o, r, d, i, n, g,  , t, o,  , t, h, ...
# 4     [t, h, e,  , s, w, e, d, i, s, h,  , b, u, y, ...
# ...                                                 ...
# 5837  [r, i, s, i, n, g,  , c, o, s, t, s,  , h, a, ...
# 5838  [n, o, r, d, i, c,  , w, a, l, k, i, n, g,  , ...
# 5839  [a, c, c, o, r, d, i, n, g,  , s, h, i, p, p, ...
# 5840  [i, n,  , t, h, e,  , b, u, i, l, d, i, n, g, ...
# 5841  [h, e, l, s, i, n, k, i,  , a, f, x,  ,  ,  , ...
#
#              tokenized_Clean_Sentence_without_stopwords
# 0     [geosolutions, technology, leverage, benefon, ...
# 1                    [esi, lows, bk, real, possibility]
# 2     [last, quarter, componenta, net, sales, double...
# 3     [according, finnish, russian, chamber, commerc...
# 4     [swedish, buyout, firm, sold, remaining, perce...
# ...                                                 ...
# 5837  [rising, costs, forced, packaging, producer, h...
# 5838  [nordic, walking, first, used, summer, trainin...
# 5839  [according, shipping, company, viking, line, e...
# 5840  [building, home, improvement, trade, sales, de...
# 5841  [helsinki, afx, kci, konecranes, said, order, ...
#
# [5836 rows x 6 columns]

# %%
word_counts = Counter([word for words in train_df['tokenized_Clean_Sentence_without_stopwords'] for word in words])
word_counts
# Out:
# Counter({'geosolutions': 2,
#          'technology': 101,
#          'leverage': 3,
#          'benefon': 10,
#          'gps': 6,
#          'solutions': 103,
#          'providing': 19,
#          'location': 12,
#          'based': 126,
#          'search': 5,
#          'communities': 3,
#          'platform': 12,
#          'relevant': 6,
#          'multimedia': 3,
#          'content': 22,
#          'new': 282,
#          'powerful': 2,
#          'commercial': 27,
#          'model': 32,
#          'esi': 1,
#          'lows': 11,
#          'bk': 2,
#          'real': 68,
#          'possibility': 2,
#          'last': 105,
#          'quarter': 342,
#          'componenta': 23,
#          'net': 500,
#          'sales': 562,
#          'doubled': 6,
#          'eurm': 100,
#          'period': 335,
#          'year': 479,
#          'earlier': 108,
#          'moved': 5,
#          'zero': 1,
#          'pre': 18,
#          'tax': 21,
#          'profit': 569,
#          'loss': 221,
#          'according': 115,
#          'finnish': 539,
#          'russian': 39,
#          'chamber': 1,
#          'commerce': 5,
#          'major': 40,
#          'construction': 94,
#          'companies': 105,
#          'finland': 338,
#          'operating': 371,
#          'russia': 74,
#          'swedish': 49,
#          'buyout': 10,
#          'firm': 28,
#          'sold': 33,
#          'remaining': 15,
#          'percent': 150,
#          'stake': 63,
#          'almost': 22,
#          'eighteen': 1,
#          'months': 71,
#          'taking': 11,
#          'company': 807,
#          'public': 24,
#          'spy': 39,
#          'wouldnt': 3,
#          'surprised': 3,
#          'see': 36,
#          'green': 16,
#          'close': 48,
#          'shells': 2,
#          'billion': 90,
#          'bg': 13,
#          'deal': 97,
#          'meets': 1,
#          'shareholder': 17,
#          'skepticism': 1,
#          'ssh': 8,
#          'communications': 43,
#          'security': 34,
#          'corp': 45,
#          'stock': 123,
#          'exchange': 68,
#          'release': 46,
#          'october': 70,
#          'pm': 28,
#          'updates': 5,
#          'full': 41,
#          'outlook': 25,
#          'estimates': 27,
#          'results': 43,
#          'remain': 32,
#          'kone': 20,
#          'rose': 101,
#          'first': 245,
#          'nine': 56,
#          'stockmann': 26,
#          'department': 16,
#          'store': 25,
#          'total': 144,
#          'floor': 7,
#          'space': 16,
#          'square': 24,
#          'metres': 14,
#          'investment': 99,
#          'project': 76,
#          'price': 135,
#          'tag': 1,
#          'eur': 1630,
#          'million': 494,
#          'circulation': 3,
#          'revenue': 68,
#          'increased': 109,
#          'sweden': 42,
#          'sap': 1,
#          'q': 46,
#          'disappoints': 1,
#          'software': 66,
#          'licenses': 2,
#          'problem': 4,
#          'cloud': 5,
#          'growth': 85,
#          'trails': 1,
#          'msft': 7,
#          'orcl': 2,
#          'goog': 11,
#          'crm': 2,
#          'adbe': 3,
#          'subdivision': 1,
#          'made': 53,
#          'revenues': 17,
#          'profits': 16,
#          'viking': 14,
#          'line': 70,
#          'canceled': 7,
#          'services': 194,
#          'ahlstrom': 22,
#          'corporation': 118,
#          'announcement': 22,
#          'shares': 228,
#          'subscribed': 18,
#          'option': 39,
#          'rights': 51,
#          'programs': 9,
#          'ii': 8,
#          'fb': 42,
#          'gone': 5,
#          'day': 70,
#          'sql': 2,
#          'server': 7,
#          'grew': 35,
#          'double': 18,
#          'digit': 1,
#          'premium': 5,
#          'growing': 17,
#          'lnnen': 10,
#          'tehtaat': 10,
#          'ceo': 89,
#          'matti': 10,
#          'karppinen': 4,
#          'aims': 17,
#          'deliver': 22,
#          'fish': 9,
#          'products': 123,
#          'customers': 92,
#          'currently': 40,
#          'share': 290,
#          'quoted': 5,
#          'nasdaq': 21,
#          'omx': 99,
#          'helsinki': 174,
#          'rautaruukki': 24,
#          'oyj': 250,
#          'rtrks': 11,
#          'elcoteq': 40,
#          'se': 9,
#          'listed': 21,
#          'ltd': 59,
#          'two': 88,
#          'contracts': 20,
#          'turntable': 1,
#          'anode': 2,
#          'vibrocompactors': 1,
#          'delivered': 29,
#          'gansu': 1,
#          'hualu': 1,
#          'aluminum': 3,
#          'co': 31,
#          'another': 26,
#          'unnamed': 5,
#          'costumer': 1,
#          'aviva': 14,
#          'friends': 8,
#          'life': 37,
#          'top': 23,
#          'forecasts': 14,
#          'ahead': 11,
#          'pound': 3,
#          'merger': 21,
#          'stead': 1,
#          'soft': 5,
#          'drink': 2,
#          'usual': 2,
#          'teho': 1,
#          'energy': 48,
#          'fresh': 6,
#          'water': 26,
#          'plans': 37,
#          'increase': 94,
#          'unit': 97,
#          'specialist': 6,
#          'staff': 41,
#          'several': 28,
#          'dozen': 1,
#          'depending': 4,
#          'market': 239,
#          'situation': 35,
#          'closed': 30,
#          'turnover': 41,
#          'four': 31,
#          'euros': 65,
#          'shire': 11,
#          'steps': 1,
#          'drive': 11,
#          'get': 20,
#          'baxalta': 7,
#          'board': 91,
#          'talking': 3,
#          'costco': 3,
#          'premier': 4,
#          'retail': 41,
#          'dividend': 65,
#          'play': 11,
#          'cost': 49,
#          'five': 23,
#          'storey': 1,
#          'eco': 3,
#          'efficient': 14,
#          'building': 88,
#          'gross': 10,
#          'area': 69,
#          'sq': 19,
#          'also': 211,
#          'include': 49,
#          'apartments': 4,
#          'installment': 1,
#          'cinema': 4,
#          'series': 10,
#          'concludes': 3,
#          'profile': 6,
#          'inventor': 3,
#          'olavi': 1,
#          'linden': 1,
#          'whose': 5,
#          'personal': 11,
#          'artistic': 1,
#          'journey': 3,
#          'work': 29,
#          'fiskars': 30,
#          'led': 8,
#          'dozens': 1,
#          'design': 49,
#          'awards': 3,
#          'welcome': 8,
#          'sector': 51,
#          'ab': 39,
#          'lindex': 5,
#          'entered': 9,
#          'agreement': 84,
#          'september': 98,
#          'whereby': 5,
#          'wholly': 7,
#          'owned': 27,
#          'subsidiary': 40,
#          'make': 41,
#          'tender': 7,
#          'offer': 41,
#          'issued': 36,
#          'huhtamaki': 17,
#          'capital': 114,
#          'markets': 77,
#          'institutional': 4,
#          'investors': 30,
#          'analysts': 15,
#          'held': 31,
#          'espoo': 18,
#          'starting': 21,
#          'time': 84,
#          'pleased': 12,
#          'tapeks': 1,
#          'noma': 1,
#          'cramo': 19,
#          'group': 326,
#          'taxes': 31,
#          'royal': 17,
#          'dutch': 9,
#          'shell': 15,
#          'buy': 78,
#          'nearly': 16,
#          'financialwire': 3,
#          'tm': 8,
#          'press': 28,
#          'service': 96,
#          'receives': 6,
#          'compensation': 5,
#          'news': 76,
#          'opinions': 2,
#          'distributions': 3,
#          'assa': 2,
#          'abloy': 2,
#          'kaupthing': 10,
#          'bank': 131,
#          'gave': 14,
#          'neutral': 5,
#          'recommendation': 9,
#          'target': 41,
#          'crowns': 4,
#          'euro': 209,
#          'lock': 1,
#          'maker': 83,
#          'item': 1,
#          'included': 21,
#          'restructuring': 22,
#          'costs': 39,
#          'diluted': 18,
#          'eps': 61,
#          'stood': 18,
#          'versus': 27,
#          'per': 155,
#          'posted': 37,
#          'lt': 14,
#          'mn': 821,
#          'aapl': 87,
#          'afternoon': 7,
#          'selloff': 1,
#          'brutal': 1,
#          'ready': 21,
#          'lose': 2,
#          'ton': 1,
#          'money': 16,
#          'tsla': 63,
#          'recalling': 5,
#          'pretty': 5,
#          'much': 19,
#          'every': 9,
#          'single': 8,
#          'x': 27,
#          'cnnbrk': 1,
#          'got': 18,
#          'short': 66,
#          'even': 15,
#          'jump': 7,
#          'trade': 44,
#          'dolce': 2,
#          'gabbana': 2,
#          'asked': 5,
#          'european': 29,
#          'union': 17,
#          'declare': 2,
#          'marimekko': 22,
#          'unikko': 2,
#          'floral': 2,
#          'pattern': 8,
#          'trademark': 9,
#          'invalid': 2,
#          'continuing': 25,
#          'dispute': 3,
#          'intercontinental': 3,
#          'hotels': 6,
#          'global': 67,
#          'room': 4,
#          'lags': 3,
#          'pension': 17,
#          'insurance': 36,
#          'varma': 3,
#          'recipient': 1,
#          'thirds': 4,
#          'earnings': 85,
#          'related': 45,
#          'cover': 22,
#          'competitive': 10,
#          'tendering': 1,
#          'portion': 6,
#          'recorded': 12,
#          'part': 90,
#          'winnings': 1,
#          'prior': 7,
#          'patent': 19,
#          'phone': 38,
#          'nokia': 127,
#          'lg': 5,
#          'still': 43,
#          'paying': 3,
#          'cut': 37,
#          'crisis': 6,
#          'chief': 34,
#          'says': 50,
#          'volume': 47,
#          'investments': 29,
#          'phases': 4,
#          'estimated': 53,
#          'usd': 98,
#          'accounted': 11,
#          'lagardere': 1,
#          'magazine': 16,
#          'division': 39,
#          'usa': 14,
#          'already': 36,
#          'carried': 18,
#          'lead': 28,
#          'reached': 11,
#          'accounting': 11,
#          'six': 32,
#          'breweries': 4,
#          'domestic': 15,
#          'beer': 29,
#          'liters': 23,
#          'august': 47,
#          'result': 99,
#          'totalled': 75,
#          'corresponding': 158,
#          'systeemitiimi': 1,
#          'resources': 20,
#          'strengthened': 6,
#          'director': 38,
#          'paul': 3,
#          'skogberg': 1,
#          'said': 516,
#          'tesco': 31,
#          'jumps': 6,
#          'fine': 13,
#          'print': 7,
#          'logs': 1,
#          'clearly': 8,
#          'improved': 20,
#          'pulpwood': 1,
#          'thus': 8,
#          'sysopen': 7,
#          'digia': 14,
#          'accordance': 12,
#          'chapter': 3,
#          'section': 10,
#          'act': 12,
#          'obtained': 5,
#          'title': 1,
#          'sentera': 2,
#          'redeemed': 1,
#          'fell': 96,
#          'eastern': 10,
#          'block': 7,
#          'changed': 7,
#          'hands': 1,
#          'bid': 25,
#          'recent': 14,
#          'deliveries': 22,
#          'refinery': 7,
#          'anrak': 1,
#          'aluminium': 8,
#          'iron': 9,
#          'ore': 11,
#          'pelletizing': 1,
#          'plant': 107,
#          'tata': 3,
#          'steel': 60,
#          'sintering': 1,
#          'plants': 30,
#          'bhushan': 3,
#          'vips': 1,
#          'similar': 11,
#          'like': 34,
#          'beginning': 19,
#          'may': 73,
#          'u': 2,
#          'sell': 61,
#          'nowwill': 1,
#          'go': 26,
#          'higher': 52,
#          'drop': 19,
#          'generated': 21,
#          'mln': 350,
#          'stora': 40,
#          'enso': 36,
#          'meetings': 3,
#          'labor': 2,
#          'authorities': 9,
#          'employment': 9,
#          'economic': 16,
#          'development': 82,
#          'centres': 5,
#          'representatives': 3,
#          'government': 25,
#          'order': 94,
#          'find': 12,
#          'astrazeneca': 29,
#          'stalwarts': 1,
#          'fade': 1,
#          'rt': 17,
#          'andrewnyquist': 1,
#          'chartology': 1,
#          'yahoo': 6,
#          'yhoo': 13,
#          'crazy': 3,
#          'looking': 31,
#          'chart': 22,
#          'nearing': 1,
#          'breakout': 24,
#          'resistance': 22,
#          'bullish': 22,
#          'stocks': 25,
#          'twitter': 2,
#          'dip': 7,
#          'gdx': 3,
#          'googl': 9,
#          'stz': 1,
#          'gold': 10,
#          'ew': 1,
#          'vz': 4,
#          'celg': 4,
#          'sbux': 15,
#          'scty': 1,
#          'geosentric': 5,
#          'decreased': 131,
#          'january': 105,
#          'march': 72,
#          'cohen': 2,
#          'steers': 2,
#          'inc': 37,
#          'representing': 21,
#          'voting': 28,
#          'recruited': 1,
#          'japan': 14,
#          'complement': 2,
#          'network': 48,
#          'locations': 9,
#          'countries': 54,
#          'worldwide': 14,
#          'paper': 73,
#          'negative': 31,
#          'territories': 3,
#          'r': 4,
#          'shedding': 2,
#          'pct': 115,
#          'upm': 37,
#          'kymmene': 19,
#          'b': 27,
#          'lower': 81,
#          'kauko': 5,
#          'telko': 7,
#          'centralized': 2,
#          'administration': 20,
#          'dissolved': 1,
#          'appropriate': 3,
#          'parts': 10,
#          'transferred': 10,
#          'activities': 25,
#          'end': 94,
#          'april': 62,
#          'june': 66,
#          'amounted': 52,
#          'bn': 37,
#          'atria': 19,
#          'chose': 2,
#          'delight': 2,
#          'attract': 4,
#          'consumers': 19,
#          'age': 2,
#          'range': 33,
#          'microwaveable': 1,
#          'meals': 2,
#          'provider': 35,
#          'affecto': 13,
#          'hel': 124,
#          'afev': 4,
#          'today': 193,
#          'slipped': 20,
#          'second': 109,
#          'us': 109,
#          'sanctions': 1,
#          'put': 19,
#          'gazprom': 2,
#          'alliance': 6,
#          'jeopardy': 1,
#          'however': 67,
#          'returned': 5,
#          'pekka': 9,
#          'eloholma': 1,
#          'totaled': 66,
#          'changes': 20,
#          'tougher': 2,
#          'competition': 20,
#          'substantially': 2,
#          'reduced': 13,
#          'demand': 35,
#          'bread': 2,
#          'packaging': 27,
#          'manufactured': 6,
#          'kauhava': 2,
#          'connection': 7,
#          'employ': 2,
#          'persons': 21,
#          'oslo': 4,
#          'silicon': 13,
#          'valley': 3,
#          'brazilian': 6,
#          'f': 14,
#          'secure': 23,
#          'signed': 50,
#          'clients': 18,
#          'online': 22,
#          'source': 10,
#          'reseller': 1,
#          'web': 17,
#          'vladimir': 3,
#          'brando': 1,
#          'saying': 8,
#          'fair': 21,
#          'value': 105,
#          'properties': 22,
#          'went': 31,
#          'dealers': 8,
#          'largely': 2,
#          'hit': 33,
#          'investor': 17,
#          'disappointment': 4,
#          'refining': 9,
#          'margin': 35,
#          'barrel': 2,
#          'performance': 36,
#          'shipping': 25,
#          'saw': 13,
#          'ebit': 17,
#          'amid': 6,
#          'fall': 35,
#          'volumes': 16,
#          'tanker': 3,
#          'rates': 16,
#          'testament': 1,
#          'quality': 29,
#          'lte': 7,
#          'solution': 51,
#          'commitment': 7,
#          'japanese': 5,
#          'added': 43,
#          'aim': 19,
#          'finalize': 1,
#          'negotiations': 41,
#          'sign': 5,
#          'start': 57,
#          'metso': 27,
#          'foundries': 3,
#          'jyvaskyla': 8,
#          'oy': 85,
#          'discontinue': 2,
#          'production': 115,
#          'polled': 1,
#          'rated': 3,
#          'accumulate': 2,
#          'three': 55,
#          'hold': 19,
#          'one': 105,
#          'agreed': 30,
#          'danish': 10,
#          'poultry': 5,
#          'combination': 5,
#          'cash': 62,
#          'yang': 1,
#          'bottom': 16,
#          'grocer': 2,
#          'faces': 6,
#          'sfo': 1,
#          'investigation': 3,
#          'outcome': 3,
#          'becoming': 5,
#          'gs': 10,
#          'engineering': 51,
#          'install': 6,
#          'valves': 2,
#          'liquefied': 3,
#          'natural': 17,
#          'gas': 23,
#          'lng': 7,
#          'built': 25,
#          'uae': 3,
#          'extraction': 2,
#          'operator': 14,
#          'gasco': 1,
#          'ruwais': 1,
#          'percentages': 1,
#          'calculated': 4,
#          'proportion': 5,
#          'number': 67,
#          'registered': 12,
#          'register': 16,
#          'grounds': 5,
#          'rumors': 3,
#          'circulating': 3,
#          'lember': 3,
#          'matter': 6,
#          'topical': 1,
#          'estonia': 29,
#          'bill': 1,
#          'drafted': 1,
#          'social': 10,
#          'affairs': 3,
#          'ministry': 5,
#          'would': 93,
#          'scrap': 2,
#          'old': 14,
#          'pensions': 2,
#          'favorable': 2,
#          'conditions': 17,
#          'moody': 1,
#          'p': 12,
#          'long': 112,
#          'term': 56,
#          'senior': 11,
#          'unsecured': 3,
#          'debt': 17,
#          'ratings': 12,
#          'lender': 2,
#          'aktia': 9,
#          'eurbn': 2,
#          'medium': 6,
#          'note': 7,
#          'emtn': 1,
#          'program': 30,
#          'recall': 13,
#          'liquidity': 6,
#          'interrupted': 5,
#          'aspocomp': 24,
#          'traded': 7,
#          'cent': 41,
#          'hargreaves': 2,
#          'lansdown': 2,
#          'bucks': 1,
#          'weak': 22,
#          'assets': 22,
#          'rise': 31,
#          'index': 33,
#          'decision': 25,
#          'means': 11,
#          'temporary': 17,
#          'lay': 33,
#          'offs': 19,
#          'fixed': 31,
#          'duration': 6,
#          'nastola': 5,
#          'units': 43,
#          'southern': 12,
#          'central': 22,
#          'respectively': 24,
#          'orders': 41,
#          'ms': 4,
#          'laakso': 1,
#          'responsible': 16,
#          'hkscan': 12,
#          'hr': 1,
#          'functions': 10,
#          'smarket': 1,
#          'areas': 26,
#          'engaged': 6,
#          'supply': 51,
#          'marine': 7,
#          'equipment': 73,
#          'associated': 6,
#          'wartsila': 11,
#          'aberdeen': 2,
#          'asset': 13,
#          'management': 75,
#          'gains': 17,
#          'foothold': 1,
#          'china': 53,
#          'dominating': 1,
#          'rail': 5,
#          'vr': 4,
#          'planning': 17,
#          'set': 38,
#          'infected': 2,
#          'passengers': 17,
#          'distance': 4,
#          'trip': 4,
#          'separate': 6,
#          'carriage': 2,
#          'november': 38,
#          'ownership': 11,
#          'exel': 10,
#          'composites': 7,
#          'designs': 12,
#          'manufactures': 15,
#          'composite': 6,
#          'profiles': 8,
#          'tubes': 3,
#          'various': 14,
#          'industrial': 40,
#          'applications': 27,
#          'reports': 49,
#          'bavelloni': 4,
#          'nst': 1,
#          'joint': 30,
#          'ventures': 3,
#          'tools': 16,
#          'completes': 4,
#          'semiproducts': 1,
#          'produced': 12,
#          'italy': 13,
#          'high': 76,
#          'diapol': 2,
#          'brand': 30,
#          'tool': 4,
#          'pending': 1,
#          'allows': 7,
#          'entire': 15,
#          'removable': 1,
#          'plate': 5,
#          'using': 25,
#          'multiple': 4,
#          'clear': 13,
#          'stamps': 1,
#          'kind': 5,
#          'upper': 3,
#          'bb': 3,
#          'overbought': 4,
#          'lights': 2,
#          'curfew': 1,
#          'curl': 1,
#          'latest': 17,
#          'bestseller': 2,
#          'treat': 2,
#          'eyes': 3,
#          'perfect': 2,
#          'reading': 3,
#          'light': 11,
#          'luceplan': 1,
#          'world': 45,
#          'largest': 52,
#          'tuesday': 25,
#          'reported': 58,
#          'prices': 46,
#          'strong': 43,
#          'hurt': 3,
#          'contract': 143,
#          'prerequisite': 1,
#          'inclusion': 2,
#          'receipt': 1,
#          'key': 30,
#          'employees': 71,
#          'acquire': 15,
#          'aspo': 28,
#          'amount': 29,
#          'determined': 3,
#          'advance': 4,
#          'maximum': 23,
#          'mr': 35,
#          'doring': 2,
#          'eaton': 2,
#          'since': 47,
#          'acted': 2,
#          'business': 250,
#          'manager': 20,
#          'power': 44,
#          'controls': 9,
#          'ft': 6,
#          'copenhagen': 4,
#          'shopping': 14,
#          'district': 10,
#          'inaugurated': 3,
#          'strengthening': 6,
#          'presence': 11,
#          'nordic': 44,
#          'capitals': 3,
#          'financial': 135,
#          'statement': 14,
#          'tikkurila': 21,
#          'discontinued': 2,
#          'operations': 150,
#          'stainless': 12,
#          'month': 60,
#          'dec': 16,
#          'surged': 7,
#          'previous': 39,
#          'name': 18,
#          'applicant': 1,
#          'jot': 1,
#          'automation': 16,
#          'oyname': 1,
#          'mammila': 1,
#          'tuomo': 1,
#          'piirainen': 1,
#          'mika': 5,
#          'kellokoski': 1,
#          'mikaapplication': 1,
#          'kolnp': 1,
#          'adate': 1,
#          'filing': 1,
#          'application': 22,
#          'publication': 5,
#          'date': 20,
#          'netflix': 2,
#          'grows': 2,
#          'efforts': 2,
#          'create': 7,
#          'loyal': 5,
#          'nflx': 16,
#          'omxn': 3,
#          'comprising': 8,
#          'points': 24,
#          'thursday': 26,
#          'nibbling': 1,
#          'small': 29,
#          'via': 35,
#          'buying': 13,
#          'min': 8,
#          'charts': 9,
#          'aker': 10,
#          'yards': 7,
#          'cruise': 7,
#          'ferries': 7,
#          'tyc': 1,
#          'break': 23,
#          'highs': 12,
#          'lots': 6,
#          'technicals': 1,
#          'great': 18,
#          'right': 23,
#          'eero': 5,
#          'katajavuori': 1,
#          'vice': 19,
#          'president': 45,
#          'human': 6,
#          'take': 51,
#          'sabbatical': 1,
#          'whats': 3,
#          'lulu': 4,
#          'numbers': 7,
#          'looked': 1,
#          'good': 44,
#          'think': 14,
#          'conference': 13,
#          'call': 13,
#          'instill': 1,
#          'confidence': 3,
#          'adjustment': 4,
#          'measures': 29,
#          'delivery': 25,
#          'capability': 4,
#          'alma': 29,
#          'media': 77,
#          'tyrvaan': 4,
#          'sanomat': 8,
#          'paikallissanomat': 6,
#          'bought': 22,
#          'suomen': 16,
#          'local': 42,
#          'papers': 13,
#          'appearing': 1,
#          'sastamala': 2,
#          'neighbouring': 2,
#          'municipalities': 5,
#          'affecting': 2,
#          'workforce': 6,
#          'implemented': 7,
#          'meeting': 34,
#          'stonesoft': 7,
#          'headquarters': 7,
#          'italahdenkatu': 1,
#          'interim': 17,
#          'report': 75,
#          'presented': 1,
#          'ilkka': 12,
#          'hiidenheimo': 1,
#          'sampo': 31,
#          'rosenlew': 2,
#          'approximately': 67,
#          'seven': 12,
#          'forest': 28,
#          'machines': 13,
#          'monthly': 7,
#          'half': 89,
#          'exported': 3,
#          'facebook': 6,
#          'near': 33,
#          'point': 17,
#          'week': 38,
#          'different': 19,
#          'technical': 23,
#          'test': 21,
#          'february': 47,
#          'broadband': 20,
#          'data': 65,
#          'communication': 21,
#          'systems': 80,
#          'teleste': 25,
#          'tltv': 7,
#          'wednesday': 29,
#          'rocketed': 2,
#          'lifted': 6,
#          'proposal': 8,
#          'free': 13,
#          'ha': 1,
#          'heeeeeere': 1,
#          ...})

# %% [markdown]
# extracting nouns for further analysis

# %%
#extracting nouns from the 'tokenized_Clean_Sentence_without_stopwords'

# %%
# Function to extract nouns from tokenized sentences
def extract_nouns(tokens):
    tagged_tokens = pos_tag(tokens)
    nouns = [token[0] for token in tagged_tokens if token[1].startswith('N')]
    return nouns

# %%
# Apply noun extraction to the 'tokenized_Clean_Sentence_without_stopwords' column
train_df['extracted_nouns'] = train_df['tokenized_Clean_Sentence_without_stopwords'].apply(extract_nouns)
train_df['extracted_nouns']
# Out:
# 0       [geosolutions, technology, leverage, solutions...
# 1                                      [esi, possibility]
# 2       [quarter, sales, eurm, period, year, tax, prof...
# 3       [chamber, commerce, construction, companies, r...
# 4       [buyout, firm, percent, stake, months, company...
#                               ...
# 5837    [costs, producer, huhtamaki, axe, jobs, manufa...
# 5838                            [summer, country, skiers]
# 5839                    [company, line, decision, impact]
# 5840    [building, home, improvement, trade, sales, eu...
# 5841    [helsinki, afx, kci, konecranes, order, metal,...
# Name: extracted_nouns, Length: 5836, dtype: object

# %%
#extracting neutral sentiments from the cleaned data set
neutral_rows = train_df[train_df['Sentiment'] == 'neutral']
neutral_rows
# Out:
#                                                Sentence Sentiment  \
# 3     According to the Finnish Russian Chamber of Co...   neutral
# 4     The Swedish buyout firm has sold its remaining...   neutral
# 9     The Stockmann department store will have a tot...   neutral
# 13             Viking Line has canceled some services .   neutral
# 14    Ahlstrom Corporation STOCK EXCHANGE ANNOUNCEME...   neutral
# ...                                                 ...       ...
# 5833  In 2008 , Kemira recorded revenue of approxima...   neutral
# 5834  Investments in product development stood at 6....   neutral
# 5838  Nordic Walking was first used as a summer trai...   neutral
# 5839  According shipping company Viking Line , the E...   neutral
# 5840  In the building and home improvement trade , s...   neutral
#
#                                          Clean_Sentence  \
# 3     according to the finnish russian chamber of co...
# 4     the swedish buyout firm has sold its remaining...
# 9     the stockmann department store will have a tot...
# 13              viking line has canceled some services
# 14    ahlstrom corporation stock exchange announceme...
# ...                                                 ...
# 5833  in   kemira recorded revenue of approximately ...
# 5834  investments in product development stood at  m...
# 5838  nordic walking was first used as a summer trai...
# 5839  according shipping company viking line  the eu...
# 5840  in the building and home improvement trade  sa...
#
#                                tokenized_Clean_Sentence  \
# 3     [according, to, the, finnish, russian, chamber...
# 4     [the, swedish, buyout, firm, has, sold, its, r...
# 9     [the, stockmann, department, store, will, have...
# 13        [viking, line, has, canceled, some, services]
# 14    [ahlstrom, corporation, stock, exchange, annou...
# ...                                                 ...
# 5833  [in, kemira, recorded, revenue, of, approximat...
# 5834  [investments, in, product, development, stood,...
# 5838  [nordic, walking, was, first, used, as, a, sum...
# 5839  [according, shipping, company, viking, line, t...
# 5840  [in, the, building, and, home, improvement, tr...
#
#                                     Lemmatized_Sentence  \
# 3     [a, c, c, o, r, d, i, n, g,  , t, o,  , t, h, ...
# 4     [t, h, e,  , s, w, e, d, i, s, h,  , b, u, y, ...
# 9     [t, h, e,  , s, t, o, c, k, m, a, n, n,  , d, ...
# 13    [v, i, k, i, n, g,  , l, i, n, e,  , h, a, s, ...
# 14    [a, h, l, s, t, r, o, m,  , c, o, r, p, o, r, ...
# ...                                                 ...
# 5833  [i, n,  ,  ,  , k, e, m, i, r, a,  , r, e, c, ...
# 5834  [i, n, v, e, s, t, m, e, n, t, s,  , i, n,  , ...
# 5838  [n, o, r, d, i, c,  , w, a, l, k, i, n, g,  , ...
# 5839  [a, c, c, o, r, d, i, n, g,  , s, h, i, p, p, ...
# 5840  [i, n,  , t, h, e,  , b, u, i, l, d, i, n, g, ...
#
#              tokenized_Clean_Sentence_without_stopwords  \
# 3     [according, finnish, russian, chamber, commerc...
# 4     [swedish, buyout, firm, sold, remaining, perce...
# 9     [stockmann, department, store, total, floor, s...
# 13                   [viking, line, canceled, services]
# 14    [ahlstrom, corporation, stock, exchange, annou...
# ...                                                 ...
# 5833  [kemira, recorded, revenue, approximately, eur...
# 5834  [investments, product, development, stood, mln...
# 5838  [nordic, walking, first, used, summer, trainin...
# 5839  [according, shipping, company, viking, line, e...
# 5840  [building, home, improvement, trade, sales, de...
#
#                                         extracted_nouns
# 3     [chamber, commerce, construction, companies, r...
# 4     [buyout, firm, percent, stake, months, company...
# 9     [department, store, floor, space, square, inve...
# 13                                     [line, services]
# 14    [corporation, stock, exchange, announcement, s...
# ...                                                 ...
# 5833                           [kemira, revenue, staff]
# 5834      [investments, product, development, mln, mln]
# 5838                          [summer, country, skiers]
# 5839                  [company, line, decision, impact]
# 5840  [building, home, improvement, trade, sales, eu...
#
# [3124 rows x 7 columns]

# %%
#extracting positive sentiment  rows from the cleaned data set
positive_rows = train_df[train_df['Sentiment'] == 'positive']
positive_rows
# Out:
#                                                Sentence Sentiment  \
# 0     The GeoSolutions technology will leverage Bene...  positive
# 2     For the last quarter of 2010 , Componenta 's n...  positive
# 5       $SPY wouldn't be surprised to see a green close  positive
# 8     Kone 's net sales rose by some 14 % year on ye...  positive
# 10    Circulation revenue has increased by 5 % in Fi...  positive
# ...                                                 ...       ...
# 5819  Last month we added to our $GILD position and ...  positive
# 5824  `` In the newly formed company YIT Stavo the l...  positive
# 5825  Friends Life lifts profits 38% and hikes divi ...  positive
# 5836  Daily Mail parent company in talks with potent...  positive
# 5841  HELSINKI AFX   KCI Konecranes said it has won ...  positive
#
#                                          Clean_Sentence  \
# 0     the geosolutions technology will leverage bene...
# 2     for the last quarter of   componenta s net sal...
# 5         spy wouldnt be surprised to see a green close
# 8     kone s net sales rose by some   year on year i...
# 10    circulation revenue has increased by   in finl...
# ...                                                 ...
# 5819  last month we added to our gild position and s...
# 5824   in the newly formed company yit stavo the loc...
# 5825  friends life lifts profits  and hikes divi ahe...
# 5836  daily mail parent company in talks with potent...
# 5841  helsinki afx   kci konecranes said it has won ...
#
#                                tokenized_Clean_Sentence  \
# 0     [the, geosolutions, technology, will, leverage...
# 2     [for, the, last, quarter, of, componenta, s, n...
# 5     [spy, wouldnt, be, surprised, to, see, a, gree...
# 8     [kone, s, net, sales, rose, by, some, year, on...
# 10    [circulation, revenue, has, increased, by, in,...
# ...                                                 ...
# 5819  [last, month, we, added, to, our, gild, positi...
# 5824  [in, the, newly, formed, company, yit, stavo, ...
# 5825  [friends, life, lifts, profits, and, hikes, di...
# 5836  [daily, mail, parent, company, in, talks, with...
# 5841  [helsinki, afx, kci, konecranes, said, it, has...
#
#                                     Lemmatized_Sentence  \
# 0     [t, h, e,  , g, e, o, s, o, l, u, t, i, o, n, ...
# 2     [f, o, r,  , t, h, e,  , l, a, s, t,  , q, u, ...
# 5     [s, p, y,  , w, o, u, l, d, n, t,  , b, e,  , ...
# 8     [k, o, n, e,  , s,  , n, e, t,  , s, a, l, e, ...
# 10    [c, i, r, c, u, l, a, t, i, o, n,  , r, e, v, ...
# ...                                                 ...
# 5819  [l, a, s, t,  , m, o, n, t, h,  , w, e,  , a, ...
# 5824  [ , i, n,  , t, h, e,  , n, e, w, l, y,  , f, ...
# 5825  [f, r, i, e, n, d, s,  , l, i, f, e,  , l, i, ...
# 5836  [d, a, i, l, y,  , m, a, i, l,  , p, a, r, e, ...
# 5841  [h, e, l, s, i, n, k, i,  , a, f, x,  ,  ,  , ...
#
#              tokenized_Clean_Sentence_without_stopwords  \
# 0     [geosolutions, technology, leverage, benefon, ...
# 2     [last, quarter, componenta, net, sales, double...
# 5          [spy, wouldnt, surprised, see, green, close]
# 8     [kone, net, sales, rose, year, year, first, ni...
# 10    [circulation, revenue, increased, finland, swe...
# ...                                                 ...
# 5819  [last, month, added, gild, position, started, ...
# 5824  [newly, formed, company, yit, stavo, local, co...
# 5825  [friends, life, lifts, profits, hikes, divi, a...
# 5836  [daily, mail, parent, company, talks, potentia...
# 5841  [helsinki, afx, kci, konecranes, said, order, ...
#
#                                         extracted_nouns
# 0     [geosolutions, technology, leverage, solutions...
# 2     [quarter, sales, eurm, period, year, tax, prof...
# 5                                   [spy, wouldnt, see]
# 8                           [sales, year, year, months]
# 10              [circulation, revenue, finland, sweden]
# ...                                                 ...
# 5819              [month, position, bwld, growth, term]
# 5824  [company, contact, network, expertise, market,...
# 5825   [friends, life, profits, hikes, aviva, takeover]
# 5836     [mail, parent, company, partners, bid, assets]
# 5841  [helsinki, afx, kci, konecranes, order, metal,...
#
# [1852 rows x 7 columns]

# %%
#extracting positive sentiment  rows from the cleaned data set
negative_rows = train_df[train_df['Sentiment'] == 'negative']
negative_rows
# Out:
#                                                Sentence Sentiment  \
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 6     Shell's $70 Billion BG Deal Meets Shareholder ...  negative
# 7     SSH COMMUNICATIONS SECURITY CORP STOCK EXCHANG...  negative
# 11    $SAP Q1 disappoints as #software licenses down...  negative
# 39    $AAPL afternoon selloff as usual will be bruta...  negative
# ...                                                 ...       ...
# 5829  $SBUX down PM, from $DB downgrade.. PT cut fro...  negative
# 5831  Finnish developer and manufacturer of mobile p...  negative
# 5832  Operating profit fell to EUR 38.1 mn from EUR ...  negative
# 5835  HSBC Says Unit to Book $585 Million Charge on ...  negative
# 5837  RISING costs have forced packaging producer Hu...  negative
#
#                                          Clean_Sentence  \
# 1           esi on lows down  to  bk a real possibility
# 6     shells  billion bg deal meets shareholder skep...
# 7     ssh communications security corp stock exchang...
# 11    sap q disappoints as software licenses down re...
# 39    aapl afternoon selloff as usual will be brutal...
# ...                                                 ...
# 5829    sbux down pm from db downgrade pt cut from  to
# 5831  finnish developer and manufacturer of mobile p...
# 5832  operating profit fell to eur  mn from eur  mn ...
# 5835  hsbc says unit to book  million charge on sett...
# 5837  rising costs have forced packaging producer hu...
#
#                                tokenized_Clean_Sentence  \
# 1     [esi, on, lows, down, to, bk, a, real, possibi...
# 6     [shells, billion, bg, deal, meets, shareholder...
# 7     [ssh, communications, security, corp, stock, e...
# 11    [sap, q, disappoints, as, software, licenses, ...
# 39    [aapl, afternoon, selloff, as, usual, will, be...
# ...                                                 ...
# 5829  [sbux, down, pm, from, db, downgrade, pt, cut,...
# 5831  [finnish, developer, and, manufacturer, of, mo...
# 5832  [operating, profit, fell, to, eur, mn, from, e...
# 5835  [hsbc, says, unit, to, book, million, charge, ...
# 5837  [rising, costs, have, forced, packaging, produ...
#
#                                     Lemmatized_Sentence  \
# 1     [e, s, i,  , o, n,  , l, o, w, s,  , d, o, w, ...
# 6     [s, h, e, l, l, s,  ,  , b, i, l, l, i, o, n, ...
# 7     [s, s, h,  , c, o, m, m, u, n, i, c, a, t, i, ...
# 11    [s, a, p,  , q,  , d, i, s, a, p, p, o, i, n, ...
# 39    [a, a, p, l,  , a, f, t, e, r, n, o, o, n,  , ...
# ...                                                 ...
# 5829  [s, b, u, x,  , d, o, w, n,  , p, m,  , f, r, ...
# 5831  [f, i, n, n, i, s, h,  , d, e, v, e, l, o, p, ...
# 5832  [o, p, e, r, a, t, i, n, g,  , p, r, o, f, i, ...
# 5835  [h, s, b, c,  , s, a, y, s,  , u, n, i, t,  , ...
# 5837  [r, i, s, i, n, g,  , c, o, s, t, s,  , h, a, ...
#
#              tokenized_Clean_Sentence_without_stopwords  \
# 1                    [esi, lows, bk, real, possibility]
# 6     [shells, billion, bg, deal, meets, shareholder...
# 7     [ssh, communications, security, corp, stock, e...
# 11    [sap, q, disappoints, software, licenses, real...
# 39    [aapl, afternoon, selloff, usual, brutal, get,...
# ...                                                 ...
# 5829                 [sbux, pm, db, downgrade, pt, cut]
# 5831  [finnish, developer, manufacturer, mobile, pho...
# 5832        [operating, profit, fell, eur, mn, eur, mn]
# 5835  [hsbc, says, unit, book, million, charge, sett...
# 5837  [rising, costs, forced, packaging, producer, h...
#
#                                         extracted_nouns
# 1                                    [esi, possibility]
# 6          [shells, bg, meets, shareholder, skepticism]
# 7     [ssh, communications, security, stock, exchang...
# 11    [sap, q, disappoints, software, problem, cloud...
# 39                     [afternoon, selloff, ton, money]
# ...                                                 ...
# 5829                            [sbux, pm, db, pt, cut]
# 5831  [developer, manufacturer, phone, chargers, omx...
# 5832                       [operating, profit, eur, mn]
# 5835             [hsbc, unit, book, charge, settlement]
# 5837  [costs, producer, huhtamaki, axe, jobs, manufa...
#
# [860 rows x 7 columns]

# %%
train_df
# Out:
#                                                Sentence Sentiment  \
# 0     The GeoSolutions technology will leverage Bene...  positive
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2     For the last quarter of 2010 , Componenta 's n...  positive
# 3     According to the Finnish Russian Chamber of Co...   neutral
# 4     The Swedish buyout firm has sold its remaining...   neutral
# ...                                                 ...       ...
# 5837  RISING costs have forced packaging producer Hu...  negative
# 5838  Nordic Walking was first used as a summer trai...   neutral
# 5839  According shipping company Viking Line , the E...   neutral
# 5840  In the building and home improvement trade , s...   neutral
# 5841  HELSINKI AFX   KCI Konecranes said it has won ...  positive
#
#                                          Clean_Sentence  \
# 0     the geosolutions technology will leverage bene...
# 1           esi on lows down  to  bk a real possibility
# 2     for the last quarter of   componenta s net sal...
# 3     according to the finnish russian chamber of co...
# 4     the swedish buyout firm has sold its remaining...
# ...                                                 ...
# 5837  rising costs have forced packaging producer hu...
# 5838  nordic walking was first used as a summer trai...
# 5839  according shipping company viking line  the eu...
# 5840  in the building and home improvement trade  sa...
# 5841  helsinki afx   kci konecranes said it has won ...
#
#                                tokenized_Clean_Sentence  \
# 0     [the, geosolutions, technology, will, leverage...
# 1     [esi, on, lows, down, to, bk, a, real, possibi...
# 2     [for, the, last, quarter, of, componenta, s, n...
# 3     [according, to, the, finnish, russian, chamber...
# 4     [the, swedish, buyout, firm, has, sold, its, r...
# ...                                                 ...
# 5837  [rising, costs, have, forced, packaging, produ...
# 5838  [nordic, walking, was, first, used, as, a, sum...
# 5839  [according, shipping, company, viking, line, t...
# 5840  [in, the, building, and, home, improvement, tr...
# 5841  [helsinki, afx, kci, konecranes, said, it, has...
#
#                                     Lemmatized_Sentence  \
# 0     [t, h, e,  , g, e, o, s, o, l, u, t, i, o, n, ...
# 1     [e, s, i,  , o, n,  , l, o, w, s,  , d, o, w, ...
# 2     [f, o, r,  , t, h, e,  , l, a, s, t,  , q, u, ...
# 3     [a, c, c, o, r, d, i, n, g,  , t, o,  , t, h, ...
# 4     [t, h, e,  , s, w, e, d, i, s, h,  , b, u, y, ...
# ...                                                 ...
# 5837  [r, i, s, i, n, g,  , c, o, s, t, s,  , h, a, ...
# 5838  [n, o, r, d, i, c,  , w, a, l, k, i, n, g,  , ...
# 5839  [a, c, c, o, r, d, i, n, g,  , s, h, i, p, p, ...
# 5840  [i, n,  , t, h, e,  , b, u, i, l, d, i, n, g, ...
# 5841  [h, e, l, s, i, n, k, i,  , a, f, x,  ,  ,  , ...
#
#              tokenized_Clean_Sentence_without_stopwords  \
# 0     [geosolutions, technology, leverage, benefon, ...
# 1                    [esi, lows, bk, real, possibility]
# 2     [last, quarter, componenta, net, sales, double...
# 3     [according, finnish, russian, chamber, commerc...
# 4     [swedish, buyout, firm, sold, remaining, perce...
# ...                                                 ...
# 5837  [rising, costs, forced, packaging, producer, h...
# 5838  [nordic, walking, first, used, summer, trainin...
# 5839  [according, shipping, company, viking, line, e...
# 5840  [building, home, improvement, trade, sales, de...
# 5841  [helsinki, afx, kci, konecranes, said, order, ...
#
#                                         extracted_nouns
# 0     [geosolutions, technology, leverage, solutions...
# 1                                    [esi, possibility]
# 2     [quarter, sales, eurm, period, year, tax, prof...
# 3     [chamber, commerce, construction, companies, r...
# 4     [buyout, firm, percent, stake, months, company...
# ...                                                 ...
# 5837  [costs, producer, huhtamaki, axe, jobs, manufa...
# 5838                          [summer, country, skiers]
# 5839                  [company, line, decision, impact]
# 5840  [building, home, improvement, trade, sales, eu...
# 5841  [helsinki, afx, kci, konecranes, order, metal,...
#
# [5836 rows x 7 columns]

# %% [markdown]
# # Explaratory Data Analysis

# %% [markdown]
# 1.word clouds

# %%
def generate_word_cloud(words, title):
    # Convert each word to a string to handle potential non-string elements
    words = [str(word) for word in words]
    
    wordcloud = WordCloud(width=800, height=400, background_color='black').generate(' '.join(words))
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
# Generate word clouds for each sentiment
generate_word_cloud(positive_rows['extracted_nouns'].explode().tolist(), 'Positive Sentiment Word Cloud')

# %%
generate_word_cloud(neutral_rows['extracted_nouns'].explode().tolist(), 'Neutral Sentiment Word Cloud')

# %%
generate_word_cloud(negative_rows['extracted_nouns'].explode().tolist(), 'Negative Sentiment Word Cloud')

# %% [markdown]
# 2. Bar Plots of Word Frequency

# %%
word_frequency = Counter([word for sublist in train_df['tokenized_Clean_Sentence_without_stopwords'] for word in sublist])
top_words = word_frequency.most_common(10)
plt.figure(figsize=(10, 6))
plt.bar(*zip(*top_words))
plt.title('Top 10 Words in the Dataset')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 3. Sentiment Distribution

# %%
sentiment_distribution = train_df['Sentiment'].value_counts()
plt.figure(figsize=(8, 5))
sentiment_distribution.plot(kind='bar', color=['green', 'gray', 'red'])
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()

# %%
#pie chart
plt.figure(figsize=(8, 8))
train_df['Sentiment'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Pie Chart of Sentiment Distribution')
plt.show()

# %% [markdown]
# 4.Noun Frequency Analysis

# %%
all_nouns = [noun for sublist in train_df['extracted_nouns'] for noun in sublist]
noun_freq = FreqDist(all_nouns)

# %%
top_n_nouns = 20

# %%
plt.figure(figsize=(10, 6))
# Extract top N nouns and their frequencies
top_n_nouns_data = noun_freq.most_common(top_n_nouns)
top_nouns, frequencies = zip(*top_n_nouns_data)
# Creating  a bar plot
plt.bar(top_nouns, frequencies, color='skyblue')
plt.title(f'Top {top_n_nouns} Most Frequent Nouns')
plt.xlabel('Nouns')
plt.ylabel('Frequency')
# Rotating x-axis labels for better visibility
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# # feature engineering

# %%
# Create a new column with sentences
train_df['cleaned_Sentence'] = train_df['tokenized_Clean_Sentence_without_stopwords'].apply(lambda x: ' '.join(x))

# Display the modified DataFrame with the new column
train_df[['Sentence', 'cleaned_Sentence']]
# Out:
#                                                Sentence  \
# 0     The GeoSolutions technology will leverage Bene...
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...
# 2     For the last quarter of 2010 , Componenta 's n...
# 3     According to the Finnish Russian Chamber of Co...
# 4     The Swedish buyout firm has sold its remaining...
# ...                                                 ...
# 5837  RISING costs have forced packaging producer Hu...
# 5838  Nordic Walking was first used as a summer trai...
# 5839  According shipping company Viking Line , the E...
# 5840  In the building and home improvement trade , s...
# 5841  HELSINKI AFX   KCI Konecranes said it has won ...
#
#                                        cleaned_Sentence
# 0     geosolutions technology leverage benefon gps s...
# 1                          esi lows bk real possibility
# 2     last quarter componenta net sales doubled eurm...
# 3     according finnish russian chamber commerce maj...
# 4     swedish buyout firm sold remaining percent sta...
# ...                                                 ...
# 5837  rising costs forced packaging producer huhtama...
# 5838  nordic walking first used summer training meth...
# 5839  according shipping company viking line eu deci...
# 5840  building home improvement trade sales decrease...
# 5841  helsinki afx kci konecranes said order four ho...
#
# [5836 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder
# Perform label encoding for the "Sentiment" column
label_encoder = LabelEncoder()
train_df['Encoded_Sentiment'] = label_encoder.fit_transform(train_df['Sentiment'])

# Display the modified DataFrame
train_df[['Sentiment','Encoded_Sentiment']]
# Out:
#      Sentiment  Encoded_Sentiment
# 0     positive                  2
# 1     negative                  0
# 2     positive                  2
# 3      neutral                  1
# 4      neutral                  1
# ...        ...                ...
# 5837  negative                  0
# 5838   neutral                  1
# 5839   neutral                  1
# 5840   neutral                  1
# 5841  positive                  2
#
# [5836 rows x 2 columns]

# %% [markdown]
# finding sentiment polarity for the cleaned_sentence using textblob

# %%
from textblob import TextBlob

# %%
from textblob import TextBlob
# Creating sentiment polarity for the cleaned_Sentence column
train_df['Sentiment_Polarity_Cleaned'] = train_df['cleaned_Sentence'].apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
# Converting sentiment polarity to sentiment labels
train_df['Sentiment_Label_Cleaned'] = train_df['Sentiment_Polarity_Cleaned'].apply(
    lambda x: 'positive' if x > 0 else ('neutral' if x == 0 else 'negative'))

# %%
# Perform label encoding for the "Sentiment" column
label_encoder = LabelEncoder()
train_df['Sentiment_Label_Encoded'] = label_encoder.fit_transform(train_df['Sentiment_Label_Cleaned'])

# Display the modified DataFrame
train_df[['Sentiment_Label_Cleaned','Sentiment_Label_Encoded']]
# Out:
#      Sentiment_Label_Cleaned  Sentiment_Label_Encoded
# 0                   positive                        2
# 1                   positive                        2
# 2                    neutral                        1
# 3                   positive                        2
# 4                   negative                        0
# ...                      ...                      ...
# 5837                negative                        0
# 5838                positive                        2
# 5839                positive                        2
# 5840                negative                        0
# 5841                positive                        2
#
# [5836 rows x 2 columns]

# %%
train_df.head(10)
# Out:
#                                             Sentence Sentiment  \
# 0  The GeoSolutions technology will leverage Bene...  positive
# 1  $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2  For the last quarter of 2010 , Componenta 's n...  positive
# 3  According to the Finnish Russian Chamber of Co...   neutral
# 4  The Swedish buyout firm has sold its remaining...   neutral
# 5    $SPY wouldn't be surprised to see a green close  positive
# 6  Shell's $70 Billion BG Deal Meets Shareholder ...  negative
# 7  SSH COMMUNICATIONS SECURITY CORP STOCK EXCHANG...  negative
# 8  Kone 's net sales rose by some 14 % year on ye...  positive
# 9  The Stockmann department store will have a tot...   neutral
#
#                                       Clean_Sentence  \
# 0  the geosolutions technology will leverage bene...
# 1        esi on lows down  to  bk a real possibility
# 2  for the last quarter of   componenta s net sal...
# 3  according to the finnish russian chamber of co...
# 4  the swedish buyout firm has sold its remaining...
# 5      spy wouldnt be surprised to see a green close
# 6  shells  billion bg deal meets shareholder skep...
# 7  ssh communications security corp stock exchang...
# 8  kone s net sales rose by some   year on year i...
# 9  the stockmann department store will have a tot...
#
#                             tokenized_Clean_Sentence  \
# 0  [the, geosolutions, technology, will, leverage...
# 1  [esi, on, lows, down, to, bk, a, real, possibi...
# 2  [for, the, last, quarter, of, componenta, s, n...
# 3  [according, to, the, finnish, russian, chamber...
# 4  [the, swedish, buyout, firm, has, sold, its, r...
# 5  [spy, wouldnt, be, surprised, to, see, a, gree...
# 6  [shells, billion, bg, deal, meets, shareholder...
# 7  [ssh, communications, security, corp, stock, e...
# 8  [kone, s, net, sales, rose, by, some, year, on...
# 9  [the, stockmann, department, store, will, have...
#
#                                  Lemmatized_Sentence  \
# 0  [t, h, e,  , g, e, o, s, o, l, u, t, i, o, n, ...
# 1  [e, s, i,  , o, n,  , l, o, w, s,  , d, o, w, ...
# 2  [f, o, r,  , t, h, e,  , l, a, s, t,  , q, u, ...
# 3  [a, c, c, o, r, d, i, n, g,  , t, o,  , t, h, ...
# 4  [t, h, e,  , s, w, e, d, i, s, h,  , b, u, y, ...
# 5  [s, p, y,  , w, o, u, l, d, n, t,  , b, e,  , ...
# 6  [s, h, e, l, l, s,  ,  , b, i, l, l, i, o, n, ...
# 7  [s, s, h,  , c, o, m, m, u, n, i, c, a, t, i, ...
# 8  [k, o, n, e,  , s,  , n, e, t,  , s, a, l, e, ...
# 9  [t, h, e,  , s, t, o, c, k, m, a, n, n,  , d, ...
#
#           tokenized_Clean_Sentence_without_stopwords  \
# 0  [geosolutions, technology, leverage, benefon, ...
# 1                 [esi, lows, bk, real, possibility]
# 2  [last, quarter, componenta, net, sales, double...
# 3  [according, finnish, russian, chamber, commerc...
# 4  [swedish, buyout, firm, sold, remaining, perce...
# 5       [spy, wouldnt, surprised, see, green, close]
# 6  [shells, billion, bg, deal, meets, shareholder...
# 7  [ssh, communications, security, corp, stock, e...
# 8  [kone, net, sales, rose, year, year, first, ni...
# 9  [stockmann, department, store, total, floor, s...
#
#                                      extracted_nouns  \
# 0  [geosolutions, technology, leverage, solutions...
# 1                                 [esi, possibility]
# 2  [quarter, sales, eurm, period, year, tax, prof...
# 3  [chamber, commerce, construction, companies, r...
# 4  [buyout, firm, percent, stake, months, company...
# 5                                [spy, wouldnt, see]
# 6       [shells, bg, meets, shareholder, skepticism]
# 7  [ssh, communications, security, stock, exchang...
# 8                        [sales, year, year, months]
# 9  [department, store, floor, space, square, inve...
#
#                                     cleaned_Sentence  Encoded_Sentiment  \
# 0  geosolutions technology leverage benefon gps s...                  2
# 1                       esi lows bk real possibility                  0
# 2  last quarter componenta net sales doubled eurm...                  2
# 3  according finnish russian chamber commerce maj...                  1
# 4  swedish buyout firm sold remaining percent sta...                  1
# 5              spy wouldnt surprised see green close                  2
# 6  shells billion bg deal meets shareholder skept...                  0
# 7  ssh communications security corp stock exchang...                  0
# 8    kone net sales rose year year first nine months                  2
# 9  stockmann department store total floor space s...                  1
#
#    Sentiment_Polarity_Cleaned Sentiment_Label_Cleaned  Sentiment_Label_Encoded
# 0                    0.209091                positive                        2
# 1                    0.200000                positive                        2
# 2                    0.000000                 neutral                        1
# 3                    0.031250                positive                        2
# 4                   -0.100000                negative                        0
# 5                   -0.050000                negative                        0
# 6                    0.000000                 neutral                        1
# 7                    0.350000                positive                        2
# 8                    0.283333                positive                        2
# 9                    0.000000                 neutral                        1

# %%
final_df=pd.DataFrame(train_df[['Sentence','Sentiment','cleaned_Sentence','Encoded_Sentiment','Sentiment_Polarity_Cleaned','Sentiment_Label_Cleaned','Sentiment_Label_Encoded']])

# %%
final_df
# Out:
#                                                Sentence Sentiment  \
# 0     The GeoSolutions technology will leverage Bene...  positive
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2     For the last quarter of 2010 , Componenta 's n...  positive
# 3     According to the Finnish Russian Chamber of Co...   neutral
# 4     The Swedish buyout firm has sold its remaining...   neutral
# ...                                                 ...       ...
# 5837  RISING costs have forced packaging producer Hu...  negative
# 5838  Nordic Walking was first used as a summer trai...   neutral
# 5839  According shipping company Viking Line , the E...   neutral
# 5840  In the building and home improvement trade , s...   neutral
# 5841  HELSINKI AFX   KCI Konecranes said it has won ...  positive
#
#                                        cleaned_Sentence  Encoded_Sentiment  \
# 0     geosolutions technology leverage benefon gps s...                  2
# 1                          esi lows bk real possibility                  0
# 2     last quarter componenta net sales doubled eurm...                  2
# 3     according finnish russian chamber commerce maj...                  1
# 4     swedish buyout firm sold remaining percent sta...                  1
# ...                                                 ...                ...
# 5837  rising costs forced packaging producer huhtama...                  0
# 5838  nordic walking first used summer training meth...                  1
# 5839  according shipping company viking line eu deci...                  1
# 5840  building home improvement trade sales decrease...                  1
# 5841  helsinki afx kci konecranes said order four ho...                  2
#
#       Sentiment_Polarity_Cleaned Sentiment_Label_Cleaned  \
# 0                       0.209091                positive
# 1                       0.200000                positive
# 2                       0.000000                 neutral
# 3                       0.031250                positive
# 4                      -0.100000                negative
# ...                          ...                     ...
# 5837                   -0.300000                negative
# 5838                    0.125000                positive
# 5839                    0.187500                positive
# 5840                   -0.400000                negative
# 5841                    0.250000                positive
#
#       Sentiment_Label_Encoded
# 0                           2
# 1                           2
# 2                           1
# 3                           2
# 4                           0
# ...                       ...
# 5837                        0
# 5838                        2
# 5839                        2
# 5840                        0
# 5841                        2
#
# [5836 rows x 7 columns]

# %%
word_counts = Counter([word for words in train_df['tokenized_Clean_Sentence_without_stopwords'] for word in words])
word_counts
# Out:
# Counter({'geosolutions': 2,
#          'technology': 101,
#          'leverage': 3,
#          'benefon': 10,
#          'gps': 6,
#          'solutions': 103,
#          'providing': 19,
#          'location': 12,
#          'based': 126,
#          'search': 5,
#          'communities': 3,
#          'platform': 12,
#          'relevant': 6,
#          'multimedia': 3,
#          'content': 22,
#          'new': 282,
#          'powerful': 2,
#          'commercial': 27,
#          'model': 32,
#          'esi': 1,
#          'lows': 11,
#          'bk': 2,
#          'real': 68,
#          'possibility': 2,
#          'last': 105,
#          'quarter': 342,
#          'componenta': 23,
#          'net': 500,
#          'sales': 562,
#          'doubled': 6,
#          'eurm': 100,
#          'period': 335,
#          'year': 479,
#          'earlier': 108,
#          'moved': 5,
#          'zero': 1,
#          'pre': 18,
#          'tax': 21,
#          'profit': 569,
#          'loss': 221,
#          'according': 115,
#          'finnish': 539,
#          'russian': 39,
#          'chamber': 1,
#          'commerce': 5,
#          'major': 40,
#          'construction': 94,
#          'companies': 105,
#          'finland': 338,
#          'operating': 371,
#          'russia': 74,
#          'swedish': 49,
#          'buyout': 10,
#          'firm': 28,
#          'sold': 33,
#          'remaining': 15,
#          'percent': 150,
#          'stake': 63,
#          'almost': 22,
#          'eighteen': 1,
#          'months': 71,
#          'taking': 11,
#          'company': 807,
#          'public': 24,
#          'spy': 39,
#          'wouldnt': 3,
#          'surprised': 3,
#          'see': 36,
#          'green': 16,
#          'close': 48,
#          'shells': 2,
#          'billion': 90,
#          'bg': 13,
#          'deal': 97,
#          'meets': 1,
#          'shareholder': 17,
#          'skepticism': 1,
#          'ssh': 8,
#          'communications': 43,
#          'security': 34,
#          'corp': 45,
#          'stock': 123,
#          'exchange': 68,
#          'release': 46,
#          'october': 70,
#          'pm': 28,
#          'updates': 5,
#          'full': 41,
#          'outlook': 25,
#          'estimates': 27,
#          'results': 43,
#          'remain': 32,
#          'kone': 20,
#          'rose': 101,
#          'first': 245,
#          'nine': 56,
#          'stockmann': 26,
#          'department': 16,
#          'store': 25,
#          'total': 144,
#          'floor': 7,
#          'space': 16,
#          'square': 24,
#          'metres': 14,
#          'investment': 99,
#          'project': 76,
#          'price': 135,
#          'tag': 1,
#          'eur': 1630,
#          'million': 494,
#          'circulation': 3,
#          'revenue': 68,
#          'increased': 109,
#          'sweden': 42,
#          'sap': 1,
#          'q': 46,
#          'disappoints': 1,
#          'software': 66,
#          'licenses': 2,
#          'problem': 4,
#          'cloud': 5,
#          'growth': 85,
#          'trails': 1,
#          'msft': 7,
#          'orcl': 2,
#          'goog': 11,
#          'crm': 2,
#          'adbe': 3,
#          'subdivision': 1,
#          'made': 53,
#          'revenues': 17,
#          'profits': 16,
#          'viking': 14,
#          'line': 70,
#          'canceled': 7,
#          'services': 194,
#          'ahlstrom': 22,
#          'corporation': 118,
#          'announcement': 22,
#          'shares': 228,
#          'subscribed': 18,
#          'option': 39,
#          'rights': 51,
#          'programs': 9,
#          'ii': 8,
#          'fb': 42,
#          'gone': 5,
#          'day': 70,
#          'sql': 2,
#          'server': 7,
#          'grew': 35,
#          'double': 18,
#          'digit': 1,
#          'premium': 5,
#          'growing': 17,
#          'lnnen': 10,
#          'tehtaat': 10,
#          'ceo': 89,
#          'matti': 10,
#          'karppinen': 4,
#          'aims': 17,
#          'deliver': 22,
#          'fish': 9,
#          'products': 123,
#          'customers': 92,
#          'currently': 40,
#          'share': 290,
#          'quoted': 5,
#          'nasdaq': 21,
#          'omx': 99,
#          'helsinki': 174,
#          'rautaruukki': 24,
#          'oyj': 250,
#          'rtrks': 11,
#          'elcoteq': 40,
#          'se': 9,
#          'listed': 21,
#          'ltd': 59,
#          'two': 88,
#          'contracts': 20,
#          'turntable': 1,
#          'anode': 2,
#          'vibrocompactors': 1,
#          'delivered': 29,
#          'gansu': 1,
#          'hualu': 1,
#          'aluminum': 3,
#          'co': 31,
#          'another': 26,
#          'unnamed': 5,
#          'costumer': 1,
#          'aviva': 14,
#          'friends': 8,
#          'life': 37,
#          'top': 23,
#          'forecasts': 14,
#          'ahead': 11,
#          'pound': 3,
#          'merger': 21,
#          'stead': 1,
#          'soft': 5,
#          'drink': 2,
#          'usual': 2,
#          'teho': 1,
#          'energy': 48,
#          'fresh': 6,
#          'water': 26,
#          'plans': 37,
#          'increase': 94,
#          'unit': 97,
#          'specialist': 6,
#          'staff': 41,
#          'several': 28,
#          'dozen': 1,
#          'depending': 4,
#          'market': 239,
#          'situation': 35,
#          'closed': 30,
#          'turnover': 41,
#          'four': 31,
#          'euros': 65,
#          'shire': 11,
#          'steps': 1,
#          'drive': 11,
#          'get': 20,
#          'baxalta': 7,
#          'board': 91,
#          'talking': 3,
#          'costco': 3,
#          'premier': 4,
#          'retail': 41,
#          'dividend': 65,
#          'play': 11,
#          'cost': 49,
#          'five': 23,
#          'storey': 1,
#          'eco': 3,
#          'efficient': 14,
#          'building': 88,
#          'gross': 10,
#          'area': 69,
#          'sq': 19,
#          'also': 211,
#          'include': 49,
#          'apartments': 4,
#          'installment': 1,
#          'cinema': 4,
#          'series': 10,
#          'concludes': 3,
#          'profile': 6,
#          'inventor': 3,
#          'olavi': 1,
#          'linden': 1,
#          'whose': 5,
#          'personal': 11,
#          'artistic': 1,
#          'journey': 3,
#          'work': 29,
#          'fiskars': 30,
#          'led': 8,
#          'dozens': 1,
#          'design': 49,
#          'awards': 3,
#          'welcome': 8,
#          'sector': 51,
#          'ab': 39,
#          'lindex': 5,
#          'entered': 9,
#          'agreement': 84,
#          'september': 98,
#          'whereby': 5,
#          'wholly': 7,
#          'owned': 27,
#          'subsidiary': 40,
#          'make': 41,
#          'tender': 7,
#          'offer': 41,
#          'issued': 36,
#          'huhtamaki': 17,
#          'capital': 114,
#          'markets': 77,
#          'institutional': 4,
#          'investors': 30,
#          'analysts': 15,
#          'held': 31,
#          'espoo': 18,
#          'starting': 21,
#          'time': 84,
#          'pleased': 12,
#          'tapeks': 1,
#          'noma': 1,
#          'cramo': 19,
#          'group': 326,
#          'taxes': 31,
#          'royal': 17,
#          'dutch': 9,
#          'shell': 15,
#          'buy': 78,
#          'nearly': 16,
#          'financialwire': 3,
#          'tm': 8,
#          'press': 28,
#          'service': 96,
#          'receives': 6,
#          'compensation': 5,
#          'news': 76,
#          'opinions': 2,
#          'distributions': 3,
#          'assa': 2,
#          'abloy': 2,
#          'kaupthing': 10,
#          'bank': 131,
#          'gave': 14,
#          'neutral': 5,
#          'recommendation': 9,
#          'target': 41,
#          'crowns': 4,
#          'euro': 209,
#          'lock': 1,
#          'maker': 83,
#          'item': 1,
#          'included': 21,
#          'restructuring': 22,
#          'costs': 39,
#          'diluted': 18,
#          'eps': 61,
#          'stood': 18,
#          'versus': 27,
#          'per': 155,
#          'posted': 37,
#          'lt': 14,
#          'mn': 821,
#          'aapl': 87,
#          'afternoon': 7,
#          'selloff': 1,
#          'brutal': 1,
#          'ready': 21,
#          'lose': 2,
#          'ton': 1,
#          'money': 16,
#          'tsla': 63,
#          'recalling': 5,
#          'pretty': 5,
#          'much': 19,
#          'every': 9,
#          'single': 8,
#          'x': 27,
#          'cnnbrk': 1,
#          'got': 18,
#          'short': 66,
#          'even': 15,
#          'jump': 7,
#          'trade': 44,
#          'dolce': 2,
#          'gabbana': 2,
#          'asked': 5,
#          'european': 29,
#          'union': 17,
#          'declare': 2,
#          'marimekko': 22,
#          'unikko': 2,
#          'floral': 2,
#          'pattern': 8,
#          'trademark': 9,
#          'invalid': 2,
#          'continuing': 25,
#          'dispute': 3,
#          'intercontinental': 3,
#          'hotels': 6,
#          'global': 67,
#          'room': 4,
#          'lags': 3,
#          'pension': 17,
#          'insurance': 36,
#          'varma': 3,
#          'recipient': 1,
#          'thirds': 4,
#          'earnings': 85,
#          'related': 45,
#          'cover': 22,
#          'competitive': 10,
#          'tendering': 1,
#          'portion': 6,
#          'recorded': 12,
#          'part': 90,
#          'winnings': 1,
#          'prior': 7,
#          'patent': 19,
#          'phone': 38,
#          'nokia': 127,
#          'lg': 5,
#          'still': 43,
#          'paying': 3,
#          'cut': 37,
#          'crisis': 6,
#          'chief': 34,
#          'says': 50,
#          'volume': 47,
#          'investments': 29,
#          'phases': 4,
#          'estimated': 53,
#          'usd': 98,
#          'accounted': 11,
#          'lagardere': 1,
#          'magazine': 16,
#          'division': 39,
#          'usa': 14,
#          'already': 36,
#          'carried': 18,
#          'lead': 28,
#          'reached': 11,
#          'accounting': 11,
#          'six': 32,
#          'breweries': 4,
#          'domestic': 15,
#          'beer': 29,
#          'liters': 23,
#          'august': 47,
#          'result': 99,
#          'totalled': 75,
#          'corresponding': 158,
#          'systeemitiimi': 1,
#          'resources': 20,
#          'strengthened': 6,
#          'director': 38,
#          'paul': 3,
#          'skogberg': 1,
#          'said': 516,
#          'tesco': 31,
#          'jumps': 6,
#          'fine': 13,
#          'print': 7,
#          'logs': 1,
#          'clearly': 8,
#          'improved': 20,
#          'pulpwood': 1,
#          'thus': 8,
#          'sysopen': 7,
#          'digia': 14,
#          'accordance': 12,
#          'chapter': 3,
#          'section': 10,
#          'act': 12,
#          'obtained': 5,
#          'title': 1,
#          'sentera': 2,
#          'redeemed': 1,
#          'fell': 96,
#          'eastern': 10,
#          'block': 7,
#          'changed': 7,
#          'hands': 1,
#          'bid': 25,
#          'recent': 14,
#          'deliveries': 22,
#          'refinery': 7,
#          'anrak': 1,
#          'aluminium': 8,
#          'iron': 9,
#          'ore': 11,
#          'pelletizing': 1,
#          'plant': 107,
#          'tata': 3,
#          'steel': 60,
#          'sintering': 1,
#          'plants': 30,
#          'bhushan': 3,
#          'vips': 1,
#          'similar': 11,
#          'like': 34,
#          'beginning': 19,
#          'may': 73,
#          'u': 2,
#          'sell': 61,
#          'nowwill': 1,
#          'go': 26,
#          'higher': 52,
#          'drop': 19,
#          'generated': 21,
#          'mln': 350,
#          'stora': 40,
#          'enso': 36,
#          'meetings': 3,
#          'labor': 2,
#          'authorities': 9,
#          'employment': 9,
#          'economic': 16,
#          'development': 82,
#          'centres': 5,
#          'representatives': 3,
#          'government': 25,
#          'order': 94,
#          'find': 12,
#          'astrazeneca': 29,
#          'stalwarts': 1,
#          'fade': 1,
#          'rt': 17,
#          'andrewnyquist': 1,
#          'chartology': 1,
#          'yahoo': 6,
#          'yhoo': 13,
#          'crazy': 3,
#          'looking': 31,
#          'chart': 22,
#          'nearing': 1,
#          'breakout': 24,
#          'resistance': 22,
#          'bullish': 22,
#          'stocks': 25,
#          'twitter': 2,
#          'dip': 7,
#          'gdx': 3,
#          'googl': 9,
#          'stz': 1,
#          'gold': 10,
#          'ew': 1,
#          'vz': 4,
#          'celg': 4,
#          'sbux': 15,
#          'scty': 1,
#          'geosentric': 5,
#          'decreased': 131,
#          'january': 105,
#          'march': 72,
#          'cohen': 2,
#          'steers': 2,
#          'inc': 37,
#          'representing': 21,
#          'voting': 28,
#          'recruited': 1,
#          'japan': 14,
#          'complement': 2,
#          'network': 48,
#          'locations': 9,
#          'countries': 54,
#          'worldwide': 14,
#          'paper': 73,
#          'negative': 31,
#          'territories': 3,
#          'r': 4,
#          'shedding': 2,
#          'pct': 115,
#          'upm': 37,
#          'kymmene': 19,
#          'b': 27,
#          'lower': 81,
#          'kauko': 5,
#          'telko': 7,
#          'centralized': 2,
#          'administration': 20,
#          'dissolved': 1,
#          'appropriate': 3,
#          'parts': 10,
#          'transferred': 10,
#          'activities': 25,
#          'end': 94,
#          'april': 62,
#          'june': 66,
#          'amounted': 52,
#          'bn': 37,
#          'atria': 19,
#          'chose': 2,
#          'delight': 2,
#          'attract': 4,
#          'consumers': 19,
#          'age': 2,
#          'range': 33,
#          'microwaveable': 1,
#          'meals': 2,
#          'provider': 35,
#          'affecto': 13,
#          'hel': 124,
#          'afev': 4,
#          'today': 193,
#          'slipped': 20,
#          'second': 109,
#          'us': 109,
#          'sanctions': 1,
#          'put': 19,
#          'gazprom': 2,
#          'alliance': 6,
#          'jeopardy': 1,
#          'however': 67,
#          'returned': 5,
#          'pekka': 9,
#          'eloholma': 1,
#          'totaled': 66,
#          'changes': 20,
#          'tougher': 2,
#          'competition': 20,
#          'substantially': 2,
#          'reduced': 13,
#          'demand': 35,
#          'bread': 2,
#          'packaging': 27,
#          'manufactured': 6,
#          'kauhava': 2,
#          'connection': 7,
#          'employ': 2,
#          'persons': 21,
#          'oslo': 4,
#          'silicon': 13,
#          'valley': 3,
#          'brazilian': 6,
#          'f': 14,
#          'secure': 23,
#          'signed': 50,
#          'clients': 18,
#          'online': 22,
#          'source': 10,
#          'reseller': 1,
#          'web': 17,
#          'vladimir': 3,
#          'brando': 1,
#          'saying': 8,
#          'fair': 21,
#          'value': 105,
#          'properties': 22,
#          'went': 31,
#          'dealers': 8,
#          'largely': 2,
#          'hit': 33,
#          'investor': 17,
#          'disappointment': 4,
#          'refining': 9,
#          'margin': 35,
#          'barrel': 2,
#          'performance': 36,
#          'shipping': 25,
#          'saw': 13,
#          'ebit': 17,
#          'amid': 6,
#          'fall': 35,
#          'volumes': 16,
#          'tanker': 3,
#          'rates': 16,
#          'testament': 1,
#          'quality': 29,
#          'lte': 7,
#          'solution': 51,
#          'commitment': 7,
#          'japanese': 5,
#          'added': 43,
#          'aim': 19,
#          'finalize': 1,
#          'negotiations': 41,
#          'sign': 5,
#          'start': 57,
#          'metso': 27,
#          'foundries': 3,
#          'jyvaskyla': 8,
#          'oy': 85,
#          'discontinue': 2,
#          'production': 115,
#          'polled': 1,
#          'rated': 3,
#          'accumulate': 2,
#          'three': 55,
#          'hold': 19,
#          'one': 105,
#          'agreed': 30,
#          'danish': 10,
#          'poultry': 5,
#          'combination': 5,
#          'cash': 62,
#          'yang': 1,
#          'bottom': 16,
#          'grocer': 2,
#          'faces': 6,
#          'sfo': 1,
#          'investigation': 3,
#          'outcome': 3,
#          'becoming': 5,
#          'gs': 10,
#          'engineering': 51,
#          'install': 6,
#          'valves': 2,
#          'liquefied': 3,
#          'natural': 17,
#          'gas': 23,
#          'lng': 7,
#          'built': 25,
#          'uae': 3,
#          'extraction': 2,
#          'operator': 14,
#          'gasco': 1,
#          'ruwais': 1,
#          'percentages': 1,
#          'calculated': 4,
#          'proportion': 5,
#          'number': 67,
#          'registered': 12,
#          'register': 16,
#          'grounds': 5,
#          'rumors': 3,
#          'circulating': 3,
#          'lember': 3,
#          'matter': 6,
#          'topical': 1,
#          'estonia': 29,
#          'bill': 1,
#          'drafted': 1,
#          'social': 10,
#          'affairs': 3,
#          'ministry': 5,
#          'would': 93,
#          'scrap': 2,
#          'old': 14,
#          'pensions': 2,
#          'favorable': 2,
#          'conditions': 17,
#          'moody': 1,
#          'p': 12,
#          'long': 112,
#          'term': 56,
#          'senior': 11,
#          'unsecured': 3,
#          'debt': 17,
#          'ratings': 12,
#          'lender': 2,
#          'aktia': 9,
#          'eurbn': 2,
#          'medium': 6,
#          'note': 7,
#          'emtn': 1,
#          'program': 30,
#          'recall': 13,
#          'liquidity': 6,
#          'interrupted': 5,
#          'aspocomp': 24,
#          'traded': 7,
#          'cent': 41,
#          'hargreaves': 2,
#          'lansdown': 2,
#          'bucks': 1,
#          'weak': 22,
#          'assets': 22,
#          'rise': 31,
#          'index': 33,
#          'decision': 25,
#          'means': 11,
#          'temporary': 17,
#          'lay': 33,
#          'offs': 19,
#          'fixed': 31,
#          'duration': 6,
#          'nastola': 5,
#          'units': 43,
#          'southern': 12,
#          'central': 22,
#          'respectively': 24,
#          'orders': 41,
#          'ms': 4,
#          'laakso': 1,
#          'responsible': 16,
#          'hkscan': 12,
#          'hr': 1,
#          'functions': 10,
#          'smarket': 1,
#          'areas': 26,
#          'engaged': 6,
#          'supply': 51,
#          'marine': 7,
#          'equipment': 73,
#          'associated': 6,
#          'wartsila': 11,
#          'aberdeen': 2,
#          'asset': 13,
#          'management': 75,
#          'gains': 17,
#          'foothold': 1,
#          'china': 53,
#          'dominating': 1,
#          'rail': 5,
#          'vr': 4,
#          'planning': 17,
#          'set': 38,
#          'infected': 2,
#          'passengers': 17,
#          'distance': 4,
#          'trip': 4,
#          'separate': 6,
#          'carriage': 2,
#          'november': 38,
#          'ownership': 11,
#          'exel': 10,
#          'composites': 7,
#          'designs': 12,
#          'manufactures': 15,
#          'composite': 6,
#          'profiles': 8,
#          'tubes': 3,
#          'various': 14,
#          'industrial': 40,
#          'applications': 27,
#          'reports': 49,
#          'bavelloni': 4,
#          'nst': 1,
#          'joint': 30,
#          'ventures': 3,
#          'tools': 16,
#          'completes': 4,
#          'semiproducts': 1,
#          'produced': 12,
#          'italy': 13,
#          'high': 76,
#          'diapol': 2,
#          'brand': 30,
#          'tool': 4,
#          'pending': 1,
#          'allows': 7,
#          'entire': 15,
#          'removable': 1,
#          'plate': 5,
#          'using': 25,
#          'multiple': 4,
#          'clear': 13,
#          'stamps': 1,
#          'kind': 5,
#          'upper': 3,
#          'bb': 3,
#          'overbought': 4,
#          'lights': 2,
#          'curfew': 1,
#          'curl': 1,
#          'latest': 17,
#          'bestseller': 2,
#          'treat': 2,
#          'eyes': 3,
#          'perfect': 2,
#          'reading': 3,
#          'light': 11,
#          'luceplan': 1,
#          'world': 45,
#          'largest': 52,
#          'tuesday': 25,
#          'reported': 58,
#          'prices': 46,
#          'strong': 43,
#          'hurt': 3,
#          'contract': 143,
#          'prerequisite': 1,
#          'inclusion': 2,
#          'receipt': 1,
#          'key': 30,
#          'employees': 71,
#          'acquire': 15,
#          'aspo': 28,
#          'amount': 29,
#          'determined': 3,
#          'advance': 4,
#          'maximum': 23,
#          'mr': 35,
#          'doring': 2,
#          'eaton': 2,
#          'since': 47,
#          'acted': 2,
#          'business': 250,
#          'manager': 20,
#          'power': 44,
#          'controls': 9,
#          'ft': 6,
#          'copenhagen': 4,
#          'shopping': 14,
#          'district': 10,
#          'inaugurated': 3,
#          'strengthening': 6,
#          'presence': 11,
#          'nordic': 44,
#          'capitals': 3,
#          'financial': 135,
#          'statement': 14,
#          'tikkurila': 21,
#          'discontinued': 2,
#          'operations': 150,
#          'stainless': 12,
#          'month': 60,
#          'dec': 16,
#          'surged': 7,
#          'previous': 39,
#          'name': 18,
#          'applicant': 1,
#          'jot': 1,
#          'automation': 16,
#          'oyname': 1,
#          'mammila': 1,
#          'tuomo': 1,
#          'piirainen': 1,
#          'mika': 5,
#          'kellokoski': 1,
#          'mikaapplication': 1,
#          'kolnp': 1,
#          'adate': 1,
#          'filing': 1,
#          'application': 22,
#          'publication': 5,
#          'date': 20,
#          'netflix': 2,
#          'grows': 2,
#          'efforts': 2,
#          'create': 7,
#          'loyal': 5,
#          'nflx': 16,
#          'omxn': 3,
#          'comprising': 8,
#          'points': 24,
#          'thursday': 26,
#          'nibbling': 1,
#          'small': 29,
#          'via': 35,
#          'buying': 13,
#          'min': 8,
#          'charts': 9,
#          'aker': 10,
#          'yards': 7,
#          'cruise': 7,
#          'ferries': 7,
#          'tyc': 1,
#          'break': 23,
#          'highs': 12,
#          'lots': 6,
#          'technicals': 1,
#          'great': 18,
#          'right': 23,
#          'eero': 5,
#          'katajavuori': 1,
#          'vice': 19,
#          'president': 45,
#          'human': 6,
#          'take': 51,
#          'sabbatical': 1,
#          'whats': 3,
#          'lulu': 4,
#          'numbers': 7,
#          'looked': 1,
#          'good': 44,
#          'think': 14,
#          'conference': 13,
#          'call': 13,
#          'instill': 1,
#          'confidence': 3,
#          'adjustment': 4,
#          'measures': 29,
#          'delivery': 25,
#          'capability': 4,
#          'alma': 29,
#          'media': 77,
#          'tyrvaan': 4,
#          'sanomat': 8,
#          'paikallissanomat': 6,
#          'bought': 22,
#          'suomen': 16,
#          'local': 42,
#          'papers': 13,
#          'appearing': 1,
#          'sastamala': 2,
#          'neighbouring': 2,
#          'municipalities': 5,
#          'affecting': 2,
#          'workforce': 6,
#          'implemented': 7,
#          'meeting': 34,
#          'stonesoft': 7,
#          'headquarters': 7,
#          'italahdenkatu': 1,
#          'interim': 17,
#          'report': 75,
#          'presented': 1,
#          'ilkka': 12,
#          'hiidenheimo': 1,
#          'sampo': 31,
#          'rosenlew': 2,
#          'approximately': 67,
#          'seven': 12,
#          'forest': 28,
#          'machines': 13,
#          'monthly': 7,
#          'half': 89,
#          'exported': 3,
#          'facebook': 6,
#          'near': 33,
#          'point': 17,
#          'week': 38,
#          'different': 19,
#          'technical': 23,
#          'test': 21,
#          'february': 47,
#          'broadband': 20,
#          'data': 65,
#          'communication': 21,
#          'systems': 80,
#          'teleste': 25,
#          'tltv': 7,
#          'wednesday': 29,
#          'rocketed': 2,
#          'lifted': 6,
#          'proposal': 8,
#          'free': 13,
#          'ha': 1,
#          'heeeeeere': 1,
#          ...})

# %% [markdown]
# # Feature extraction

# %% [markdown]
# UNI-GRAM Analysis

# %%
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import ngrams
import pandas as pd

# Function for text preprocessing
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    
    # Remove punctuation and special characters
    text = ''.join([char for char in text if char not in string.punctuation and char.isalnum() or char.isspace()])
    
    # Tokenize the text
    tokens = word_tokenize(text)
    
    # Remove stop words
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    
    return tokens

# Tokenize and preprocess the sentences into words
train_df['tokenized_words'] = train_df['cleaned_Sentence'].apply(preprocess_text)

# Extract unigrams 
train_df['unigrams'] = train_df['tokenized_words'].apply(lambda x: list(ngrams(x, 1)))

# Flatten the list of unigrams
all_unigrams = [unigram for sentence_unigrams in train_df['unigrams'] for unigram in sentence_unigrams]

# Convert the results to a DataFrame for visualization
unigrams_df = pd.DataFrame(all_unigrams, columns=['Word1'])

# Display the most common unigrams
common_unigrams = unigrams_df['Word1'].value_counts().reset_index().rename(columns={'index': 'Word1', 'Word1': 'Frequency'})
print(common_unigrams.head(10))
# Out:
#      Word1  Frequency
# 0      eur       1630
# 1       mn        821
# 2  company        807
# 3   profit        569
# 4    sales        562
# 5  finnish        539
# 6     said        516
# 7      net        500
# 8  million        494
# 9     year        479

# %%
# Display the most common unigrams
top_n = 10
common_unigrams.columns = ['Word1', 'Frequency']  # Assuming the correct column names
common_unigrams['Word1'] = common_unigrams['Word1'].astype(str)  # Convert 'Word1' column to string type

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Frequency', y='Word1', data=common_unigrams.head(top_n), palette='viridis')
plt.xlabel('Frequency')
plt.ylabel('Word')
plt.title(f'Top {top_n} Most Common Unigrams')
plt.show()

# %% [markdown]
# BI-GRAM ANALYSIS

# %%
# Extract bigrams
train_df['bigrams'] = train_df['tokenized_words'].apply(lambda x: list(ngrams(x, 2)))

# Flatten the list of bigrams
all_bigrams = [bigram for sentence_bigrams in train_df['bigrams'] for bigram in sentence_bigrams]

# Convert the results to a DataFrame for visualization
bigrams_df = pd.DataFrame(all_bigrams, columns=['Word1', 'Word2'])

# Combine the two words in each bigram into a single string for better visualization
bigrams_df['Bigram'] = bigrams_df['Word1'] + ' ' + bigrams_df['Word2']

# Display the most common bigrams
common_bigrams = bigrams_df['Bigram'].value_counts().reset_index().rename(columns={'index': 'Bigram', 'Bigram': 'Frequency'})
print(common_bigrams.head(10))
# Out:
#                  Bigram  Frequency
# 0                eur mn        777
# 1             net sales        276
# 2           eur million        245
# 3      operating profit        238
# 4                mn eur        195
# 5  corresponding period        148
# 6              euro mln        135
# 7              mln euro        130
# 8            net profit        127
# 9            profit eur        115

# %%
# Display the most common unigrams
top_n = 10
common_bigrams.columns = ['Word1', 'Frequency']  # Assuming the correct column names
common_bigrams['Word1'] = common_bigrams['Word1'].astype(str)  # Convert 'Word1' column to string type

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Frequency', y='Word1', data=common_bigrams.head(top_n), palette='viridis')
plt.xlabel('Frequency')
plt.ylabel('Word')
plt.title(f'Top {top_n} Most Common bigrams')
plt.show()

# %% [markdown]
# TRI-GRAM ANALYSIS

# %%
# Extract trigrams
train_df['trigrams'] = train_df['tokenized_words'].apply(lambda x: list(ngrams(x, 3)))

# Flatten the list of trigrams
all_trigrams = [trigram for sentence_trigrams in train_df['trigrams'] for trigram in sentence_trigrams]

# Convert the results to a DataFrame for visualization
trigrams_df = pd.DataFrame(all_trigrams, columns=['Word1', 'Word2', 'Word3'])

# Combine the three words in each trigram into a single string for better visualization
trigrams_df['Trigram'] = trigrams_df['Word1'] + ' ' + trigrams_df['Word2'] + ' ' + trigrams_df['Word3']

# Display the most common trigrams
common_trigrams = trigrams_df['Trigram'].value_counts().reset_index().rename(columns={'index': 'Trigram', 'Trigram': 'Frequency'})
print(common_trigrams.head(10))
# Out:
#                    Trigram  Frequency
# 0                mn eur mn        193
# 1               eur mn eur        191
# 2             mln euro mln        126
# 3  mn corresponding period         85
# 4     eur mn corresponding         85
# 5          eur mn compared         74
# 6            profit eur mn         71
# 7          totalled eur mn         69
# 8          eur million usd         52
# 9            net sales eur         51

# %%
# Display the most common unigrams
top_n = 10
common_trigrams.columns = ['Word1', 'Frequency']  # Assuming the correct column names
common_trigrams['Word1'] = common_trigrams['Word1'].astype(str)  # Convert 'Word1' column to string type

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Frequency', y='Word1', data=common_trigrams.head(top_n), palette='viridis')
plt.xlabel('Frequency')
plt.ylabel('Word')
plt.title(f'Top {top_n} Most Common trigrams')
plt.show()

# %%
final_df
# Out:
#                                                Sentence Sentiment  \
# 0     The GeoSolutions technology will leverage Bene...  positive
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2     For the last quarter of 2010 , Componenta 's n...  positive
# 3     According to the Finnish Russian Chamber of Co...   neutral
# 4     The Swedish buyout firm has sold its remaining...   neutral
# ...                                                 ...       ...
# 5837  RISING costs have forced packaging producer Hu...  negative
# 5838  Nordic Walking was first used as a summer trai...   neutral
# 5839  According shipping company Viking Line , the E...   neutral
# 5840  In the building and home improvement trade , s...   neutral
# 5841  HELSINKI AFX   KCI Konecranes said it has won ...  positive
#
#                                        cleaned_Sentence  Encoded_Sentiment  \
# 0     geosolutions technology leverage benefon gps s...                  2
# 1                          esi lows bk real possibility                  0
# 2     last quarter componenta net sales doubled eurm...                  2
# 3     according finnish russian chamber commerce maj...                  1
# 4     swedish buyout firm sold remaining percent sta...                  1
# ...                                                 ...                ...
# 5837  rising costs forced packaging producer huhtama...                  0
# 5838  nordic walking first used summer training meth...                  1
# 5839  according shipping company viking line eu deci...                  1
# 5840  building home improvement trade sales decrease...                  1
# 5841  helsinki afx kci konecranes said order four ho...                  2
#
#       Sentiment_Polarity_Cleaned Sentiment_Label_Cleaned  \
# 0                       0.209091                positive
# 1                       0.200000                positive
# 2                       0.000000                 neutral
# 3                       0.031250                positive
# 4                      -0.100000                negative
# ...                          ...                     ...
# 5837                   -0.300000                negative
# 5838                    0.125000                positive
# 5839                    0.187500                positive
# 5840                   -0.400000                negative
# 5841                    0.250000                positive
#
#       Sentiment_Label_Encoded
# 0                           2
# 1                           2
# 2                           1
# 3                           2
# 4                           0
# ...                       ...
# 5837                        0
# 5838                        2
# 5839                        2
# 5840                        0
# 5841                        2
#
# [5836 rows x 7 columns]

# %%
import pandas as pd

# Assuming final_df is your DataFrame
# Replace 'output_file.csv' with your desired file name and path
csv_file_path = 'final_df.csv'

# Save the DataFrame to a CSV file
final_df.to_csv(csv_file_path, index=False)

print(f"CSV file '{csv_file_path}' has been created.")
# Out:
# CSV file 'final_df.csv' has been created.

# %%
final_df
# Out:
#                                                Sentence Sentiment  \
# 0     The GeoSolutions technology will leverage Bene...  positive
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2     For the last quarter of 2010 , Componenta 's n...  positive
# 3     According to the Finnish Russian Chamber of Co...   neutral
# 4     The Swedish buyout firm has sold its remaining...   neutral
# ...                                                 ...       ...
# 5837  RISING costs have forced packaging producer Hu...  negative
# 5838  Nordic Walking was first used as a summer trai...   neutral
# 5839  According shipping company Viking Line , the E...   neutral
# 5840  In the building and home improvement trade , s...   neutral
# 5841  HELSINKI AFX   KCI Konecranes said it has won ...  positive
#
#                                        cleaned_Sentence  Encoded_Sentiment  \
# 0     geosolutions technology leverage benefon gps s...                  2
# 1                          esi lows bk real possibility                  0
# 2     last quarter componenta net sales doubled eurm...                  2
# 3     according finnish russian chamber commerce maj...                  1
# 4     swedish buyout firm sold remaining percent sta...                  1
# ...                                                 ...                ...
# 5837  rising costs forced packaging producer huhtama...                  0
# 5838  nordic walking first used summer training meth...                  1
# 5839  according shipping company viking line eu deci...                  1
# 5840  building home improvement trade sales decrease...                  1
# 5841  helsinki afx kci konecranes said order four ho...                  2
#
#       Sentiment_Polarity_Cleaned Sentiment_Label_Cleaned  \
# 0                       0.209091                positive
# 1                       0.200000                positive
# 2                       0.000000                 neutral
# 3                       0.031250                positive
# 4                      -0.100000                negative
# ...                          ...                     ...
# 5837                   -0.300000                negative
# 5838                    0.125000                positive
# 5839                    0.187500                positive
# 5840                   -0.400000                negative
# 5841                    0.250000                positive
#
#       Sentiment_Label_Encoded
# 0                           2
# 1                           2
# 2                           1
# 3                           2
# 4                           0
# ...                       ...
# 5837                        0
# 5838                        2
# 5839                        2
# 5840                        0
# 5841                        2
#
# [5836 rows x 7 columns]

# %% [markdown]
# # Model building

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(final_df['cleaned_Sentence'], final_df['Sentiment_Label_Encoded'], test_size=0.2, random_state=42)
# Initialize the CountVectorizer
vectorizer = CountVectorizer()

# %% [markdown]
# # ensemble method to improve model

# %% [markdown]
# #XG BOOST

# %%
from xgboost import XGBClassifier

# %%
model = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('classifier', XGBClassifier())
])

# %%
model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('classifier',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=None, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric=None,
#                                feature_types=None, gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=None, n_jobs=None,
#                                num_parallel_tree=None,
#                                objective='multi:softprob', ...))])

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

# %%
from sklearn.metrics import accuracy_score

# Predictions on the training set
y_train_pred = model.predict(X_train)

# Predictions on the test set (already done in your code)
y_test_pred = model.predict(X_test)

# Calculate training accuracy
accuracy_train = accuracy_score(y_train, y_train_pred)

# Calculate test accuracy
accuracy_test = accuracy_score(y_test, y_test_pred)

# %%
# Print the accuracies
print(f'Training Accuracy: {accuracy_train:.2f}')
print(f'Test Accuracy: {accuracy_test:.2f}')
# Out:
# Training Accuracy: 0.94
# Test Accuracy: 0.90

# %%
print(f'Accuracy: {accuracy:.2f}')
print('\nClassification Report:\n', classification_rep)
print('\nConfusion Matrix:\n', conf_matrix)
# Out:
# Accuracy: 0.86
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.69      0.79       186
#            1       0.82      0.99      0.90       632
#            2       0.96      0.72      0.82       350
#
#     accuracy                           0.86      1168
#    macro avg       0.90      0.80      0.83      1168
# weighted avg       0.88      0.86      0.86      1168
#
#
# Confusion Matrix:
#  [[128  50   8]
#  [  2 627   3]
#  [ 10  89 251]]

# %%
# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=model.classes_, yticklabels=model.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# Overview:
# The baseline model, which predicts all instances as class 1, achieves an accuracy of 54%.
#
# We improved model achieves a significantly higher accuracy of 90%, demonstrating its effectiveness.
#
# The improved model shows good precision, recall, and F1-score for all classes, indicating a balanced performance across the different sentiment classes.
#
# The confusion matrix for the improved model provides a detailed breakdown of correct and incorrect predictions for each class.

# %%
from joblib import dump

# %%
dump(model, 'model.sav')
# Out:
# ['model.sav']
